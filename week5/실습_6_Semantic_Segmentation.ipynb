# %% [markdown]
# ### OUTTA AI 부트캠프 딥러닝반 5-1차 실습 : Semantic Segmentation

# %% [markdown]
# <h4><div style="text-align: right"> Last Edit: July 09, 2024. </div> <br>

# %% [markdown]
# ## 우선, 다음의 코드들을 실행하여 실습에 사용할 데이터셋과 파일들을 현재 ipynb 파일에 연결하도록 하자.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !cp /content/drive/MyDrive/OUTTA/week5/SE_dataset.zip /content/
# !cp /content/drive/MyDrive/OUTTA/week5/bilinear_upsampled_VGG16.pth /content/
# !cp /content/drive/MyDrive/OUTTA/week5/functions.py /content/

# %%
# !unzip "/content/SE_dataset.zip"
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#   inflating: img/2011_001600.jpg
#   inflating: img/2011_001601.jpg
#   inflating: img/2011_001602.jpg
#   inflating: img/2011_001605.jpg
#   inflating: img/2011_001606.jpg
#   inflating: img/2011_001607.jpg
#   inflating: img/2011_001608.jpg
#   inflating: img/2011_001610.jpg
#   inflating: img/2011_001611.jpg
#   inflating: img/2011_001612.jpg
#   inflating: img/2011_001613.jpg
#   inflating: img/2011_001614.jpg
#   inflating: img/2011_001616.jpg
#   inflating: img/2011_001618.jpg
#   inflating: img/2011_001619.jpg
#   inflating: img/2011_001620.jpg
#   inflating: img/2011_001621.jpg
#   inflating: img/2011_001622.jpg
#   inflating: img/2011_001624.jpg
#   inflating: img/2011_001625.jpg
#   inflating: img/2011_001627.jpg
#   inflating: img/2011_001628.jpg
#   inflating: img/2011_001629.jpg
#   inflating: img/2011_001632.jpg
#   inflating: img/2011_001637.jpg
#   inflating: img/2011_001641.jpg
#   inflating: img/2011_001642.jpg
#   inflating: img/2011_001643.jpg
#   inflating: img/2011_001645.jpg
#   inflating: img/2011_001647.jpg
#   inflating: img/2011_001649.jpg
#   inflating: img/2011_001650.jpg
#   inflating: img/2011_001652.jpg
#   inflating: img/2011_001653.jpg
#   inflating: img/2011_001655.jpg
#   inflating: img/2011_001656.jpg
#   inflating: img/2011_001662.jpg
#   inflating: img/2011_001663.jpg
#   inflating: img/2011_001665.jpg
#   inflating: img/2011_001666.jpg
#   inflating: img/2011_001668.jpg
#   inflating: img/2011_001669.jpg
#   inflating: img/2011_001671.jpg
#   inflating: img/2011_001672.jpg
#   inflating: img/2011_001673.jpg
#   inflating: img/2011_001674.jpg
#   inflating: img/2011_001678.jpg
#   inflating: img/2011_001679.jpg
#   inflating: img/2011_001687.jpg
#   inflating: img/2011_001689.jpg
#   inflating: img/2011_001691.jpg
#   inflating: img/2011_001693.jpg
#   inflating: img/2011_001694.jpg
#   inflating: img/2011_001695.jpg
#   inflating: img/2011_001698.jpg
#   inflating: img/2011_001699.jpg
#   inflating: img/2011_001700.jpg
#   inflating: img/2011_001705.jpg
#   inflating: img/2011_001707.jpg
#   inflating: img/2011_001708.jpg
#   inflating: img/2011_001710.jpg
#   inflating: img/2011_001712.jpg
#   inflating: img/2011_001713.jpg
#   inflating: img/2011_001714.jpg
#   inflating: img/2011_001715.jpg
#   inflating: img/2011_001716.jpg
#   inflating: img/2011_001718.jpg
#   inflating: img/2011_001719.jpg
#   inflating: img/2011_001720.jpg
#   inflating: img/2011_001722.jpg
#   inflating: img/2011_001726.jpg
#   inflating: img/2011_001727.jpg
#   inflating: img/2011_001728.jpg
#   inflating: img/2011_001730.jpg
#   inflating: img/2011_001732.jpg
#   inflating: img/2011_001733.jpg
#   inflating: img/2011_001739.jpg
#   inflating: img/2011_001740.jpg
#   inflating: img/2011_001741.jpg
#   inflating: img/2011_001743.jpg
#   inflating: img/2011_001745.jpg
#   inflating: img/2011_001747.jpg
#   inflating: img/2011_001748.jpg
#   inflating: img/2011_001751.jpg
#   inflating: img/2011_001753.jpg
#   inflating: img/2011_001754.jpg
#   inflating: img/2011_001755.jpg
#   inflating: img/2011_001757.jpg
#   inflating: img/2011_001764.jpg
#   inflating: img/2011_001765.jpg
#   inflating: img/2011_001766.jpg
#   inflating: img/2011_001767.jpg
#   inflating: img/2011_001769.jpg
#   inflating: img/2011_001770.jpg
#   inflating: img/2011_001771.jpg
#   inflating: img/2011_001775.jpg
#   inflating: img/2011_001776.jpg
#   inflating: img/2011_001779.jpg
#   inflating: img/2011_001782.jpg
#   inflating: img/2011_001785.jpg
#   inflating: img/2011_001789.jpg
#   inflating: img/2011_001790.jpg
#   inflating: img/2011_001791.jpg
#   inflating: img/2011_001792.jpg
#   inflating: img/2011_001793.jpg
#   inflating: img/2011_001794.jpg
#   inflating: img/2011_001796.jpg
#   inflating: img/2011_001799.jpg
#   inflating: img/2011_001800.jpg
#   inflating: img/2011_001801.jpg
#   inflating: img/2011_001803.jpg
#   inflating: img/2011_001805.jpg
#   inflating: img/2011_001806.jpg
#   inflating: img/2011_001810.jpg
#   inflating: img/2011_001811.jpg
#   inflating: img/2011_001812.jpg
#   inflating: img/2011_001815.jpg
#   inflating: img/2011_001819.jpg
#   inflating: img/2011_001820.jpg
#   inflating: img/2011_001821.jpg
#   inflating: img/2011_001822.jpg
#   inflating: img/2011_001824.jpg
#   inflating: img/2011_001825.jpg
#   inflating: img/2011_001826.jpg
#   inflating: img/2011_001827.jpg
#   inflating: img/2011_001833.jpg
#   inflating: img/2011_001834.jpg
#   inflating: img/2011_001837.jpg
#   inflating: img/2011_001839.jpg
#   inflating: img/2011_001840.jpg
#   inflating: img/2011_001841.jpg
#   inflating: img/2011_001842.jpg
#   inflating: img/2011_001845.jpg
#   inflating: img/2011_001847.jpg
#   inflating: img/2011_001854.jpg
#   inflating: img/2011_001855.jpg
#   inflating: img/2011_001856.jpg
#   inflating: img/2011_001858.jpg
#   inflating: img/2011_001860.jpg
#   inflating: img/2011_001861.jpg
#   inflating: img/2011_001862.jpg
#   inflating: img/2011_001863.jpg
#   inflating: img/2011_001866.jpg
#   inflating: img/2011_001868.jpg
#   inflating: img/2011_001870.jpg
#   inflating: img/2011_001871.jpg
#   inflating: img/2011_001872.jpg
#   inflating: img/2011_001873.jpg
#   inflating: img/2011_001875.jpg
#   inflating: img/2011_001876.jpg
#   inflating: img/2011_001877.jpg
#   inflating: img/2011_001878.jpg
#   inflating: img/2011_001880.jpg
#   inflating: img/2011_001884.jpg
#   inflating: img/2011_001885.jpg
#   inflating: img/2011_001886.jpg
#   inflating: img/2011_001889.jpg
#   inflating: img/2011_001891.jpg
#   inflating: img/2011_001893.jpg
#   inflating: img/2011_001894.jpg
#   inflating: img/2011_001895.jpg
#   inflating: img/2011_001896.jpg
#   inflating: img/2011_001900.jpg
#   inflating: img/2011_001901.jpg
#   inflating: img/2011_001902.jpg
#   inflating: img/2011_001903.jpg
#   inflating: img/2011_001904.jpg
#   inflating: img/2011_001906.jpg
#   inflating: img/2011_001909.jpg
#   inflating: img/2011_001910.jpg
#   inflating: img/2011_001911.jpg
#   inflating: img/2011_001914.jpg
#   inflating: img/2011_001915.jpg
#   inflating: img/2011_001919.jpg
#   inflating: img/2011_001920.jpg
#   inflating: img/2011_001921.jpg
#   inflating: img/2011_001922.jpg
#   inflating: img/2011_001924.jpg
#   inflating: img/2011_001926.jpg
#   inflating: img/2011_001927.jpg
#   inflating: img/2011_001928.jpg
#   inflating: img/2011_001929.jpg
#   inflating: img/2011_001930.jpg
#   inflating: img/2011_001932.jpg
#   inflating: img/2011_001937.jpg
#   inflating: img/2011_001938.jpg
#   inflating: img/2011_001941.jpg
#   inflating: img/2011_001942.jpg
#   inflating: img/2011_001944.jpg
#   inflating: img/2011_001945.jpg
#   inflating: img/2011_001946.jpg
#   inflating: img/2011_001949.jpg
#   inflating: img/2011_001950.jpg
#   inflating: img/2011_001951.jpg
#   inflating: img/2011_001952.jpg
#   inflating: img/2011_001955.jpg
#   inflating: img/2011_001956.jpg
#   inflating: img/2011_001958.jpg
#   inflating: img/2011_001959.jpg
#   inflating: img/2011_001961.jpg
#   inflating: img/2011_001962.jpg
#   inflating: img/2011_001964.jpg
#   inflating: img/2011_001966.jpg
#   inflating: img/2011_001967.jpg
#   inflating: img/2011_001971.jpg
#   inflating: img/2011_001972.jpg
#   inflating: img/2011_001974.jpg
#   inflating: img/2011_001975.jpg
#   inflating: img/2011_001977.jpg
#   inflating: img/2011_001979.jpg
#   inflating: img/2011_001980.jpg
#   inflating: img/2011_001982.jpg
#   inflating: img/2011_001984.jpg
#   inflating: img/2011_001986.jpg
#   inflating: img/2011_001987.jpg
#   inflating: img/2011_001988.jpg
#   inflating: img/2011_001989.jpg
#   inflating: img/2011_001991.jpg
#   inflating: img/2011_001994.jpg
#   inflating: img/2011_002002.jpg
#   inflating: img/2011_002003.jpg
#   inflating: img/2011_002004.jpg
#   inflating: img/2011_002005.jpg
#   inflating: img/2011_002006.jpg
#   inflating: img/2011_002012.jpg
#   inflating: img/2011_002016.jpg
#   inflating: img/2011_002018.jpg
#   inflating: img/2011_002019.jpg
#   inflating: img/2011_002021.jpg
#   inflating: img/2011_002022.jpg
#   inflating: img/2011_002026.jpg
#   inflating: img/2011_002027.jpg
#   inflating: img/2011_002031.jpg
#   inflating: img/2011_002033.jpg
#   inflating: img/2011_002034.jpg
#   inflating: img/2011_002036.jpg
#   inflating: img/2011_002038.jpg
#   inflating: img/2011_002039.jpg
#   inflating: img/2011_002040.jpg
#   inflating: img/2011_002041.jpg
#   inflating: img/2011_002042.jpg
#   inflating: img/2011_002044.jpg
#   inflating: img/2011_002045.jpg
#   inflating: img/2011_002046.jpg
#   inflating: img/2011_002047.jpg
#   inflating: img/2011_002049.jpg
#   inflating: img/2011_002050.jpg
#   inflating: img/2011_002051.jpg
#   inflating: img/2011_002052.jpg
#   inflating: img/2011_002053.jpg
#   inflating: img/2011_002055.jpg
#   inflating: img/2011_002062.jpg
#   inflating: img/2011_002063.jpg
#   inflating: img/2011_002064.jpg
#   inflating: img/2011_002070.jpg
#   inflating: img/2011_002072.jpg
#   inflating: img/2011_002073.jpg
#   inflating: img/2011_002074.jpg
#   inflating: img/2011_002075.jpg
#   inflating: img/2011_002079.jpg
#   inflating: img/2011_002085.jpg
#   inflating: img/2011_002088.jpg
#   inflating: img/2011_002091.jpg
#   inflating: img/2011_002093.jpg
#   inflating: img/2011_002096.jpg
#   inflating: img/2011_002097.jpg
#   inflating: img/2011_002098.jpg
#   inflating: img/2011_002100.jpg
#   inflating: img/2011_002102.jpg
#   inflating: img/2011_002105.jpg
#   inflating: img/2011_002106.jpg
#   inflating: img/2011_002107.jpg
#   inflating: img/2011_002108.jpg
#   inflating: img/2011_002109.jpg
#   inflating: img/2011_002110.jpg
#   inflating: img/2011_002111.jpg
#   inflating: img/2011_002113.jpg
#   inflating: img/2011_002114.jpg
#   inflating: img/2011_002116.jpg
#   inflating: img/2011_002119.jpg
#   inflating: img/2011_002120.jpg
#   inflating: img/2011_002121.jpg
#   inflating: img/2011_002124.jpg
#   inflating: img/2011_002128.jpg
#   inflating: img/2011_002129.jpg
#   inflating: img/2011_002131.jpg
#   inflating: img/2011_002132.jpg
#   inflating: img/2011_002134.jpg
#   inflating: img/2011_002135.jpg
#   inflating: img/2011_002137.jpg
#   inflating: img/2011_002142.jpg
#   inflating: img/2011_002143.jpg
#   inflating: img/2011_002144.jpg
#   inflating: img/2011_002147.jpg
#   inflating: img/2011_002148.jpg
#   inflating: img/2011_002149.jpg
#   inflating: img/2011_002150.jpg
#   inflating: img/2011_002152.jpg
#   inflating: img/2011_002154.jpg
#   inflating: img/2011_002156.jpg
#   inflating: img/2011_002158.jpg
#   inflating: img/2011_002159.jpg
#   inflating: img/2011_002160.jpg
#   inflating: img/2011_002163.jpg
#   inflating: img/2011_002167.jpg
#   inflating: img/2011_002168.jpg
#   inflating: img/2011_002169.jpg
#   inflating: img/2011_002173.jpg
#   inflating: img/2011_002174.jpg
#   inflating: img/2011_002177.jpg
#   inflating: img/2011_002178.jpg
#   inflating: img/2011_002179.jpg
#   inflating: img/2011_002181.jpg
#   inflating: img/2011_002184.jpg
#   inflating: img/2011_002185.jpg
#   inflating: img/2011_002186.jpg
#   inflating: img/2011_002189.jpg
#   inflating: img/2011_002191.jpg
#   inflating: img/2011_002192.jpg
#   inflating: img/2011_002193.jpg
#   inflating: img/2011_002196.jpg
#   inflating: img/2011_002200.jpg
#   inflating: img/2011_002202.jpg
#   inflating: img/2011_002203.jpg
#   inflating: img/2011_002211.jpg
#   inflating: img/2011_002212.jpg
#   inflating: img/2011_002215.jpg
#   inflating: img/2011_002217.jpg
#   inflating: img/2011_002218.jpg
#   inflating: img/2011_002221.jpg
#   inflating: img/2011_002222.jpg
#   inflating: img/2011_002223.jpg
#   inflating: img/2011_002224.jpg
#   inflating: img/2011_002226.jpg
#   inflating: img/2011_002227.jpg
#   inflating: img/2011_002228.jpg
#   inflating: img/2011_002230.jpg
#   inflating: img/2011_002234.jpg
#   inflating: img/2011_002236.jpg
#   inflating: img/2011_002237.jpg
#   inflating: img/2011_002239.jpg
#   inflating: img/2011_002241.jpg
#   inflating: img/2011_002242.jpg
#   inflating: img/2011_002244.jpg
#   inflating: img/2011_002245.jpg
#   inflating: img/2011_002246.jpg
#   inflating: img/2011_002247.jpg
#   inflating: img/2011_002248.jpg
#   inflating: img/2011_002251.jpg
#   inflating: img/2011_002252.jpg
#   inflating: img/2011_002253.jpg
#   inflating: img/2011_002260.jpg
#   inflating: img/2011_002265.jpg
#   inflating: img/2011_002268.jpg
#   inflating: img/2011_002269.jpg
#   inflating: img/2011_002270.jpg
#   inflating: img/2011_002272.jpg
#   inflating: img/2011_002273.jpg
#   inflating: img/2011_002276.jpg
#   inflating: img/2011_002278.jpg
#   inflating: img/2011_002279.jpg
#   inflating: img/2011_002280.jpg
#   inflating: img/2011_002281.jpg
#   inflating: img/2011_002284.jpg
#   inflating: img/2011_002286.jpg
#   inflating: img/2011_002287.jpg
#   inflating: img/2011_002291.jpg
#   inflating: img/2011_002292.jpg
#   inflating: img/2011_002294.jpg
#   inflating: img/2011_002295.jpg
#   inflating: img/2011_002298.jpg
#   inflating: img/2011_002300.jpg
#   inflating: img/2011_002301.jpg
#   inflating: img/2011_002303.jpg
#   inflating: img/2011_002308.jpg
#   inflating: img/2011_002309.jpg
#   inflating: img/2011_002312.jpg
#   inflating: img/2011_002313.jpg
#   inflating: img/2011_002317.jpg
#   inflating: img/2011_002318.jpg
#   inflating: img/2011_002322.jpg
#   inflating: img/2011_002324.jpg
#   inflating: img/2011_002325.jpg
#   inflating: img/2011_002327.jpg
#   inflating: img/2011_002330.jpg
#   inflating: img/2011_002335.jpg
#   inflating: img/2011_002341.jpg
#   inflating: img/2011_002343.jpg
#   inflating: img/2011_002346.jpg
#   inflating: img/2011_002347.jpg
#   inflating: img/2011_002348.jpg
#   inflating: img/2011_002350.jpg
#   inflating: img/2011_002357.jpg
#   inflating: img/2011_002358.jpg
#   inflating: img/2011_002359.jpg
#   inflating: img/2011_002360.jpg
#   inflating: img/2011_002362.jpg
#   inflating: img/2011_002365.jpg
#   inflating: img/2011_002366.jpg
#   inflating: img/2011_002369.jpg
#   inflating: img/2011_002371.jpg
#   inflating: img/2011_002376.jpg
#   inflating: img/2011_002379.jpg
#   inflating: img/2011_002380.jpg
#   inflating: img/2011_002381.jpg
#   inflating: img/2011_002382.jpg
#   inflating: img/2011_002384.jpg
#   inflating: img/2011_002385.jpg
#   inflating: img/2011_002386.jpg
#   inflating: img/2011_002387.jpg
#   inflating: img/2011_002388.jpg
#   inflating: img/2011_002389.jpg
#   inflating: img/2011_002391.jpg
#   inflating: img/2011_002393.jpg
#   inflating: img/2011_002394.jpg
#   inflating: img/2011_002395.jpg
#   inflating: img/2011_002396.jpg
#   inflating: img/2011_002397.jpg
#   inflating: img/2011_002398.jpg
#   inflating: img/2011_002402.jpg
#   inflating: img/2011_002406.jpg
#   inflating: img/2011_002407.jpg
#   inflating: img/2011_002409.jpg
#   inflating: img/2011_002410.jpg
#   inflating: img/2011_002413.jpg
#   inflating: img/2011_002414.jpg
#   inflating: img/2011_002418.jpg
#   inflating: img/2011_002419.jpg
#   inflating: img/2011_002420.jpg
#   inflating: img/2011_002421.jpg
#   inflating: img/2011_002422.jpg
#   inflating: img/2011_002428.jpg
#   inflating: img/2011_002429.jpg
#   inflating: img/2011_002432.jpg
#   inflating: img/2011_002433.jpg
#   inflating: img/2011_002435.jpg
#   inflating: img/2011_002436.jpg
#   inflating: img/2011_002443.jpg
#   inflating: img/2011_002447.jpg
#   inflating: img/2011_002448.jpg
#   inflating: img/2011_002453.jpg
#   inflating: img/2011_002455.jpg
#   inflating: img/2011_002457.jpg
#   inflating: img/2011_002458.jpg
#   inflating: img/2011_002459.jpg
#   inflating: img/2011_002460.jpg
#   inflating: img/2011_002461.jpg
#   inflating: img/2011_002462.jpg
#   inflating: img/2011_002463.jpg
#   inflating: img/2011_002464.jpg
#   inflating: img/2011_002470.jpg
#   inflating: img/2011_002474.jpg
#   inflating: img/2011_002476.jpg
#   inflating: img/2011_002478.jpg
#   inflating: img/2011_002479.jpg
#   inflating: img/2011_002482.jpg
#   inflating: img/2011_002484.jpg
#   inflating: img/2011_002488.jpg
#   inflating: img/2011_002490.jpg
#   inflating: img/2011_002491.jpg
#   inflating: img/2011_002492.jpg
#   inflating: img/2011_002494.jpg
#   inflating: img/2011_002495.jpg
#   inflating: img/2011_002498.jpg
#   inflating: img/2011_002503.jpg
#   inflating: img/2011_002504.jpg
#   inflating: img/2011_002505.jpg
#   inflating: img/2011_002506.jpg
#   inflating: img/2011_002507.jpg
#   inflating: img/2011_002509.jpg
#   inflating: img/2011_002511.jpg
#   inflating: img/2011_002514.jpg
#   inflating: img/2011_002515.jpg
#   inflating: img/2011_002516.jpg
#   inflating: img/2011_002517.jpg
#   inflating: img/2011_002519.jpg
#   inflating: img/2011_002520.jpg
#   inflating: img/2011_002526.jpg
#   inflating: img/2011_002528.jpg
#   inflating: img/2011_002531.jpg
#   inflating: img/2011_002532.jpg
#   inflating: img/2011_002533.jpg
#   inflating: img/2011_002535.jpg
#   inflating: img/2011_002536.jpg
#   inflating: img/2011_002542.jpg
#   inflating: img/2011_002543.jpg
#   inflating: img/2011_002548.jpg
#   inflating: img/2011_002550.jpg
#   inflating: img/2011_002551.jpg
#   inflating: img/2011_002552.jpg
#   inflating: img/2011_002553.jpg
#   inflating: img/2011_002554.jpg
#   inflating: img/2011_002555.jpg
#   inflating: img/2011_002556.jpg
#   inflating: img/2011_002558.jpg
#   inflating: img/2011_002559.jpg
#   inflating: img/2011_002560.jpg
#   inflating: img/2011_002561.jpg
#   inflating: img/2011_002565.jpg
#   inflating: img/2011_002566.jpg
#   inflating: img/2011_002567.jpg
#   inflating: img/2011_002568.jpg
#   inflating: img/2011_002571.jpg
#   inflating: img/2011_002575.jpg
#   inflating: img/2011_002577.jpg
#   inflating: img/2011_002578.jpg
#   inflating: img/2011_002579.jpg
#   inflating: img/2011_002581.jpg
#   inflating: img/2011_002582.jpg
#   inflating: img/2011_002583.jpg
#   inflating: img/2011_002584.jpg
#   inflating: img/2011_002585.jpg
#   inflating: img/2011_002586.jpg
#   inflating: img/2011_002588.jpg
#   inflating: img/2011_002589.jpg
#   inflating: img/2011_002590.jpg
#   inflating: img/2011_002592.jpg
#   inflating: img/2011_002594.jpg
#   inflating: img/2011_002598.jpg
#   inflating: img/2011_002601.jpg
#   inflating: img/2011_002603.jpg
#   inflating: img/2011_002605.jpg
#   inflating: img/2011_002606.jpg
#   inflating: img/2011_002609.jpg
#   inflating: img/2011_002610.jpg
#   inflating: img/2011_002612.jpg
#   inflating: img/2011_002614.jpg
#   inflating: img/2011_002616.jpg
#   inflating: img/2011_002617.jpg
#   inflating: img/2011_002618.jpg
#   inflating: img/2011_002620.jpg
#   inflating: img/2011_002623.jpg
#   inflating: img/2011_002624.jpg
#   inflating: img/2011_002627.jpg
#   inflating: img/2011_002628.jpg
#   inflating: img/2011_002629.jpg
#   inflating: img/2011_002631.jpg
#   inflating: img/2011_002636.jpg
#   inflating: img/2011_002638.jpg
#   inflating: img/2011_002639.jpg
#   inflating: img/2011_002640.jpg
#   inflating: img/2011_002641.jpg
#   inflating: img/2011_002644.jpg
#   inflating: img/2011_002649.jpg
#   inflating: img/2011_002650.jpg
#   inflating: img/2011_002651.jpg
#   inflating: img/2011_002652.jpg
#   inflating: img/2011_002656.jpg
#   inflating: img/2011_002657.jpg
#   inflating: img/2011_002658.jpg
#   inflating: img/2011_002661.jpg
#   inflating: img/2011_002662.jpg
#   inflating: img/2011_002663.jpg
#   inflating: img/2011_002664.jpg
#   inflating: img/2011_002668.jpg
#   inflating: img/2011_002673.jpg
#   inflating: img/2011_002674.jpg
#   inflating: img/2011_002675.jpg
#   inflating: img/2011_002676.jpg
#   inflating: img/2011_002677.jpg
#   inflating: img/2011_002678.jpg
#   inflating: img/2011_002679.jpg
#   inflating: img/2011_002683.jpg
#   inflating: img/2011_002685.jpg
#   inflating: img/2011_002687.jpg
#   inflating: img/2011_002690.jpg
#   inflating: img/2011_002691.jpg
#   inflating: img/2011_002694.jpg
#   inflating: img/2011_002697.jpg
#   inflating: img/2011_002699.jpg
#   inflating: img/2011_002704.jpg
#   inflating: img/2011_002706.jpg
#   inflating: img/2011_002708.jpg
#   inflating: img/2011_002709.jpg
#   inflating: img/2011_002713.jpg
#   inflating: img/2011_002714.jpg
#   inflating: img/2011_002715.jpg
#   inflating: img/2011_002717.jpg
#   inflating: img/2011_002719.jpg
#   inflating: img/2011_002723.jpg
#   inflating: img/2011_002724.jpg
#   inflating: img/2011_002725.jpg
#   inflating: img/2011_002726.jpg
#   inflating: img/2011_002730.jpg
#   inflating: img/2011_002738.jpg
#   inflating: img/2011_002740.jpg
#   inflating: img/2011_002742.jpg
#   inflating: img/2011_002744.jpg
#   inflating: img/2011_002745.jpg
#   inflating: img/2011_002746.jpg
#   inflating: img/2011_002748.jpg
#   inflating: img/2011_002750.jpg
#   inflating: img/2011_002751.jpg
#   inflating: img/2011_002752.jpg
#   inflating: img/2011_002754.jpg
#   inflating: img/2011_002756.jpg
#   inflating: img/2011_002760.jpg
#   inflating: img/2011_002762.jpg
#   inflating: img/2011_002765.jpg
#   inflating: img/2011_002766.jpg
#   inflating: img/2011_002767.jpg
#   inflating: img/2011_002770.jpg
#   inflating: img/2011_002772.jpg
#   inflating: img/2011_002775.jpg
#   inflating: img/2011_002776.jpg
#   inflating: img/2011_002777.jpg
#   inflating: img/2011_002779.jpg
#   inflating: img/2011_002780.jpg
#   inflating: img/2011_002782.jpg
#   inflating: img/2011_002784.jpg
#   inflating: img/2011_002786.jpg
#   inflating: img/2011_002787.jpg
#   inflating: img/2011_002789.jpg
#   inflating: img/2011_002790.jpg
#   inflating: img/2011_002793.jpg
#   inflating: img/2011_002795.jpg
#   inflating: img/2011_002796.jpg
#   inflating: img/2011_002797.jpg
#   inflating: img/2011_002798.jpg
#   inflating: img/2011_002802.jpg
#   inflating: img/2011_002803.jpg
#   inflating: img/2011_002805.jpg
#   inflating: img/2011_002808.jpg
#   inflating: img/2011_002810.jpg
#   inflating: img/2011_002811.jpg
#   inflating: img/2011_002812.jpg
#   inflating: img/2011_002814.jpg
#   inflating: img/2011_002817.jpg
#   inflating: img/2011_002818.jpg
#   inflating: img/2011_002821.jpg
#   inflating: img/2011_002822.jpg
#   inflating: img/2011_002823.jpg
#   inflating: img/2011_002826.jpg
#   inflating: img/2011_002830.jpg
#   inflating: img/2011_002831.jpg
#   inflating: img/2011_002833.jpg
#   inflating: img/2011_002834.jpg
#   inflating: img/2011_002837.jpg
#   inflating: img/2011_002838.jpg
#   inflating: img/2011_002841.jpg
#   inflating: img/2011_002842.jpg
#   inflating: img/2011_002851.jpg
#   inflating: img/2011_002852.jpg
#   inflating: img/2011_002853.jpg
#   inflating: img/2011_002854.jpg
#   inflating: img/2011_002857.jpg
#   inflating: img/2011_002863.jpg
#   inflating: img/2011_002864.jpg
#   inflating: img/2011_002867.jpg
#   inflating: img/2011_002868.jpg
#   inflating: img/2011_002870.jpg
#   inflating: img/2011_002871.jpg
#   inflating: img/2011_002872.jpg
#   inflating: img/2011_002873.jpg
#   inflating: img/2011_002877.jpg
#   inflating: img/2011_002879.jpg
#   inflating: img/2011_002880.jpg
#   inflating: img/2011_002881.jpg
#   inflating: img/2011_002883.jpg
#   inflating: img/2011_002884.jpg
#   inflating: img/2011_002885.jpg
#   inflating: img/2011_002887.jpg
#   inflating: img/2011_002889.jpg
#   inflating: img/2011_002890.jpg
#   inflating: img/2011_002897.jpg
#   inflating: img/2011_002900.jpg
#   inflating: img/2011_002904.jpg
#   inflating: img/2011_002908.jpg
#   inflating: img/2011_002911.jpg
#   inflating: img/2011_002912.jpg
#   inflating: img/2011_002913.jpg
#   inflating: img/2011_002915.jpg
#   inflating: img/2011_002916.jpg
#   inflating: img/2011_002917.jpg
#   inflating: img/2011_002920.jpg
#   inflating: img/2011_002921.jpg
#   inflating: img/2011_002924.jpg
#   inflating: img/2011_002925.jpg
#   inflating: img/2011_002927.jpg
#   inflating: img/2011_002929.jpg
#   inflating: img/2011_002930.jpg
#   inflating: img/2011_002931.jpg
#   inflating: img/2011_002932.jpg
#   inflating: img/2011_002933.jpg
#   inflating: img/2011_002935.jpg
#   inflating: img/2011_002937.jpg
#   inflating: img/2011_002938.jpg
#   inflating: img/2011_002940.jpg
#   inflating: img/2011_002942.jpg
#   inflating: img/2011_002943.jpg
#   inflating: img/2011_002944.jpg
#   inflating: img/2011_002946.jpg
#   inflating: img/2011_002947.jpg
#   inflating: img/2011_002949.jpg
#   inflating: img/2011_002951.jpg
#   inflating: img/2011_002953.jpg
#   inflating: img/2011_002956.jpg
#   inflating: img/2011_002958.jpg
#   inflating: img/2011_002962.jpg
#   inflating: img/2011_002964.jpg
#   inflating: img/2011_002965.jpg
#   inflating: img/2011_002966.jpg
#   inflating: img/2011_002967.jpg
#   inflating: img/2011_002969.jpg
#   inflating: img/2011_002970.jpg
#   inflating: img/2011_002971.jpg
#   inflating: img/2011_002974.jpg
#   inflating: img/2011_002975.jpg
#   inflating: img/2011_002978.jpg
#   inflating: img/2011_002979.jpg
#   inflating: img/2011_002980.jpg
#   inflating: img/2011_002981.jpg
#   inflating: img/2011_002983.jpg
#   inflating: img/2011_002985.jpg
#   inflating: img/2011_002987.jpg
#   inflating: img/2011_002988.jpg
#   inflating: img/2011_002992.jpg
#   inflating: img/2011_002993.jpg
#   inflating: img/2011_002994.jpg
#   inflating: img/2011_002996.jpg
#   inflating: img/2011_002997.jpg
#   inflating: img/2011_002999.jpg
#   inflating: img/2011_003002.jpg
#   inflating: img/2011_003003.jpg
#   inflating: img/2011_003005.jpg
#   inflating: img/2011_003010.jpg
#   inflating: img/2011_003011.jpg
#   inflating: img/2011_003012.jpg
#   inflating: img/2011_003013.jpg
#   inflating: img/2011_003016.jpg
#   inflating: img/2011_003019.jpg
#   inflating: img/2011_003020.jpg
#   inflating: img/2011_003021.jpg
#   inflating: img/2011_003023.jpg
#   inflating: img/2011_003025.jpg
#   inflating: img/2011_003027.jpg
#   inflating: img/2011_003028.jpg
#   inflating: img/2011_003029.jpg
#   inflating: img/2011_003030.jpg
#   inflating: img/2011_003034.jpg
#   inflating: img/2011_003037.jpg
#   inflating: img/2011_003038.jpg
#   inflating: img/2011_003039.jpg
#   inflating: img/2011_003041.jpg
#   inflating: img/2011_003043.jpg
#   inflating: img/2011_003044.jpg
#   inflating: img/2011_003047.jpg
#   inflating: img/2011_003048.jpg
#   inflating: img/2011_003049.jpg
#   inflating: img/2011_003050.jpg
#   inflating: img/2011_003054.jpg
#   inflating: img/2011_003055.jpg
#   inflating: img/2011_003057.jpg
#   inflating: img/2011_003059.jpg
#   inflating: img/2011_003063.jpg
#   inflating: img/2011_003065.jpg
#   inflating: img/2011_003066.jpg
#   inflating: img/2011_003069.jpg
#   inflating: img/2011_003073.jpg
#   inflating: img/2011_003074.jpg
#   inflating: img/2011_003076.jpg
#   inflating: img/2011_003078.jpg
#   inflating: img/2011_003079.jpg
#   inflating: img/2011_003081.jpg
#   inflating: img/2011_003082.jpg
#   inflating: img/2011_003085.jpg
#   inflating: img/2011_003086.jpg
#   inflating: img/2011_003089.jpg
#   inflating: img/2011_003091.jpg
#   inflating: img/2011_003094.jpg
#   inflating: img/2011_003097.jpg
#   inflating: img/2011_003098.jpg
#   inflating: img/2011_003103.jpg
#   inflating: img/2011_003106.jpg
#   inflating: img/2011_003109.jpg
#   inflating: img/2011_003111.jpg
#   inflating: img/2011_003114.jpg
#   inflating: img/2011_003115.jpg
#   inflating: img/2011_003118.jpg
#   inflating: img/2011_003121.jpg
#   inflating: img/2011_003124.jpg
#   inflating: img/2011_003128.jpg
#   inflating: img/2011_003132.jpg
#   inflating: img/2011_003134.jpg
#   inflating: img/2011_003136.jpg
#   inflating: img/2011_003138.jpg
#   inflating: img/2011_003141.jpg
#   inflating: img/2011_003144.jpg
#   inflating: img/2011_003145.jpg
#   inflating: img/2011_003146.jpg
#   inflating: img/2011_003148.jpg
#   inflating: img/2011_003149.jpg
#   inflating: img/2011_003150.jpg
#   inflating: img/2011_003151.jpg
#   inflating: img/2011_003152.jpg
#   inflating: img/2011_003154.jpg
#   inflating: img/2011_003158.jpg
#   inflating: img/2011_003159.jpg
#   inflating: img/2011_003160.jpg
#   inflating: img/2011_003162.jpg
#   inflating: img/2011_003163.jpg
#   inflating: img/2011_003166.jpg
#   inflating: img/2011_003167.jpg
#   inflating: img/2011_003168.jpg
#   inflating: img/2011_003169.jpg
#   inflating: img/2011_003171.jpg
#   inflating: img/2011_003172.jpg
#   inflating: img/2011_003176.jpg
#   inflating: img/2011_003177.jpg
#   inflating: img/2011_003182.jpg
#   inflating: img/2011_003183.jpg
#   inflating: img/2011_003184.jpg
#   inflating: img/2011_003185.jpg
#   inflating: img/2011_003187.jpg
#   inflating: img/2011_003188.jpg
#   inflating: img/2011_003190.jpg
#   inflating: img/2011_003192.jpg
#   inflating: img/2011_003194.jpg
#   inflating: img/2011_003197.jpg
#   inflating: img/2011_003201.jpg
#   inflating: img/2011_003203.jpg
#   inflating: img/2011_003205.jpg
#   inflating: img/2011_003206.jpg
#   inflating: img/2011_003207.jpg
#   inflating: img/2011_003211.jpg
#   inflating: img/2011_003212.jpg
#   inflating: img/2011_003213.jpg
#   inflating: img/2011_003216.jpg
#   inflating: img/2011_003220.jpg
#   inflating: img/2011_003223.jpg
#   inflating: img/2011_003228.jpg
#   inflating: img/2011_003229.jpg
#   inflating: img/2011_003230.jpg
#   inflating: img/2011_003232.jpg
#   inflating: img/2011_003236.jpg
#   inflating: img/2011_003237.jpg
#   inflating: img/2011_003238.jpg
#   inflating: img/2011_003240.jpg
#   inflating: img/2011_003242.jpg
#   inflating: img/2011_003244.jpg
#   inflating: img/2011_003246.jpg
#   inflating: img/2011_003247.jpg
#   inflating: img/2011_003250.jpg
#   inflating: img/2011_003253.jpg
#   inflating: img/2011_003254.jpg
#   inflating: img/2011_003255.jpg
#   inflating: img/2011_003256.jpg
#   inflating: img/2011_003258.jpg
#   inflating: img/2011_003259.jpg
#   inflating: img/2011_003260.jpg
#   inflating: img/2011_003261.jpg
#   inflating: img/2011_003262.jpg
#   inflating: img/2011_003269.jpg
#   inflating: img/2011_003271.jpg
#   inflating: img/2011_003272.jpg
#   inflating: img/2011_003273.jpg
#   inflating: img/2011_003274.jpg
#   inflating: img/2011_003275.jpg
#   inflating: img/2011_003276.jpg
#   inflating: img/2011_003279.jpg
#   inflating: img/2011_003280.jpg
#   inflating: img/2011_003285.jpg
#   inflating: img/2011_003286.jpg
#   inflating: img/2011_003287.jpg
#   inflating: img/2011_003292.jpg
#   inflating: img/2011_003294.jpg
#   inflating: img/2011_003298.jpg
#   inflating: img/2011_003299.jpg
#   inflating: img/2011_003300.jpg
#   inflating: img/2011_003301.jpg
#   inflating: img/2011_003303.jpg
#   inflating: img/2011_003304.jpg
#   inflating: img/2011_003305.jpg
#   inflating: img/2011_003306.jpg
#   inflating: img/2011_003308.jpg
#   inflating: img/2011_003309.jpg
#   inflating: img/2011_003311.jpg
#   inflating: img/2011_003314.jpg
#   inflating: img/2011_003316.jpg
#   inflating: img/2011_003320.jpg
#   inflating: img/2011_003322.jpg
#   inflating: img/2011_003324.jpg
#   inflating: img/2011_003325.jpg
#   inflating: img/2011_003326.jpg
#   inflating: img/2011_003331.jpg
#   inflating: img/2011_003337.jpg
#   inflating: img/2011_003339.jpg
#   inflating: img/2011_003343.jpg
#   inflating: img/2011_003344.jpg
#   inflating: img/2011_003346.jpg
#   inflating: img/2011_003348.jpg
#   inflating: img/2011_003349.jpg
#   inflating: img/2011_003352.jpg
#   inflating: img/2011_003353.jpg
#   inflating: img/2011_003357.jpg
#   inflating: img/2011_003358.jpg
#   inflating: img/2011_003361.jpg
#   inflating: img/2011_003362.jpg
#   inflating: img/2011_003364.jpg
#   inflating: img/2011_003365.jpg
#   inflating: img/2011_003367.jpg
#   inflating: img/2011_003369.jpg
#   inflating: img/2011_003372.jpg
#   inflating: img/2011_003374.jpg
#   inflating: img/2011_003375.jpg
#   inflating: img/2011_003376.jpg
#   inflating: img/2011_003379.jpg
#   inflating: img/2011_003380.jpg
#   inflating: img/2011_003381.jpg
#   inflating: img/2011_003382.jpg
#   inflating: img/2011_003383.jpg
#   inflating: img/2011_003387.jpg
#   inflating: img/2011_003390.jpg
#   inflating: img/2011_003391.jpg
#   inflating: img/2011_003392.jpg
#   inflating: img/2011_003393.jpg
#   inflating: img/2011_003395.jpg
#   inflating: img/2011_003396.jpg
#   inflating: img/2011_003401.jpg
#   inflating: img/2011_003406.jpg
#   inflating: img/2011_003409.jpg
#   inflating: img/2011_003410.jpg
#   inflating: img/2011_003412.jpg
#   inflating: img/2011_003413.jpg
#   inflating: img/2011_003418.jpg
#   inflating: img/2011_003419.jpg
#   inflating: img/2011_003420.jpg
#   inflating: img/2011_003422.jpg
#   inflating: img/2011_003424.jpg
#   inflating: img/2011_003425.jpg
#   inflating: img/2011_003426.jpg
#   inflating: img/2011_003427.jpg
#   inflating: img/2011_003429.jpg
#   inflating: img/2011_003430.jpg
#   inflating: img/2011_003432.jpg
#   inflating: img/2011_003433.jpg
#   inflating: img/2011_003436.jpg
#   inflating: img/2011_003438.jpg
#   inflating: img/2011_003439.jpg
#   inflating: img/2011_003440.jpg
#   inflating: img/2011_003441.jpg
#   inflating: img/2011_003445.jpg
#   inflating: img/2011_003447.jpg
#   inflating: img/2011_003449.jpg
#   inflating: img/2011_003450.jpg
#   inflating: img/2011_003452.jpg
#   inflating: img/2011_003453.jpg
#   inflating: img/2011_003455.jpg
#   inflating: img/2011_003456.jpg
#   inflating: img/2011_003459.jpg
#   inflating: img/2011_003463.jpg
#   inflating: img/2011_003465.jpg
#   inflating: img/2011_003468.jpg
#   inflating: img/2011_003471.jpg
#   inflating: img/2011_003473.jpg
#   inflating: img/2011_003474.jpg
#   inflating: img/2011_003475.jpg
#   inflating: img/2011_003476.jpg
#   inflating: img/2011_003477.jpg
#   inflating: img/2011_003482.jpg
#   inflating: img/2011_003483.jpg
#   inflating: img/2011_003484.jpg
#   inflating: img/2011_003486.jpg
#   inflating: img/2011_003488.jpg
#   inflating: img/2011_003490.jpg
#   inflating: img/2011_003491.jpg
#   inflating: img/2011_003492.jpg
#   inflating: img/2011_003493.jpg
#   inflating: img/2011_003494.jpg
#   inflating: img/2011_003495.jpg
#   inflating: img/2011_003497.jpg
#   inflating: img/2011_003505.jpg
#   inflating: img/2011_003506.jpg
#   inflating: img/2011_003511.jpg
#   inflating: img/2011_003513.jpg
#   inflating: img/2011_003514.jpg
#   inflating: img/2011_003515.jpg
#   inflating: img/2011_003516.jpg
#   inflating: img/2011_003518.jpg
#   inflating: img/2011_003520.jpg
#   inflating: img/2011_003522.jpg
#   inflating: img/2011_003524.jpg
#   inflating: img/2011_003526.jpg
#   inflating: img/2011_003527.jpg
#   inflating: img/2011_003530.jpg
#   inflating: img/2011_003534.jpg
#   inflating: img/2011_003535.jpg
#   inflating: img/2011_003536.jpg
#   inflating: img/2011_003538.jpg
#   inflating: img/2011_003540.jpg
#   inflating: img/2011_003545.jpg
#   inflating: img/2011_003548.jpg
#   inflating: img/2011_003552.jpg
#   inflating: img/2011_003554.jpg
#   inflating: img/2011_003556.jpg
#   inflating: img/2011_003557.jpg
#   inflating: img/2011_003559.jpg
#   inflating: img/2011_003560.jpg
#   inflating: img/2011_003561.jpg
#   inflating: img/2011_003562.jpg
#   inflating: img/2011_003563.jpg
#   inflating: img/2011_003566.jpg
#   inflating: img/2011_003567.jpg
#   inflating: img/2011_003570.jpg
#   inflating: img/2011_003571.jpg
#   inflating: img/2011_003572.jpg
#   inflating: img/2011_003576.jpg
#   inflating: img/2011_003580.jpg
#   inflating: img/2011_003583.jpg
#   inflating: img/2011_003585.jpg
#   inflating: img/2011_003589.jpg
#   inflating: img/2011_003591.jpg
#   inflating: img/2011_003594.jpg
#   inflating: img/2011_003598.jpg
#   inflating: img/2011_003600.jpg
#   inflating: img/2011_003601.jpg
#   inflating: img/2011_003602.jpg
#   inflating: img/2011_003603.jpg
#   inflating: img/2011_003604.jpg
#   inflating: img/2011_003605.jpg
#   inflating: img/2011_003609.jpg
#   inflating: img/2011_003611.jpg
#   inflating: img/2011_003613.jpg
#   inflating: img/2011_003616.jpg
#   inflating: img/2011_003617.jpg
#   inflating: img/2011_003618.jpg
#   inflating: img/2011_003619.jpg
#   inflating: img/2011_003622.jpg
#   inflating: img/2011_003623.jpg
#   inflating: img/2011_003625.jpg
#   inflating: img/2011_003628.jpg
#   inflating: img/2011_003629.jpg
#   inflating: img/2011_003631.jpg
#   inflating: img/2011_003634.jpg
#   inflating: img/2011_003636.jpg
#   inflating: img/2011_003637.jpg
#   inflating: img/2011_003638.jpg
#   inflating: img/2011_003639.jpg
#   inflating: img/2011_003641.jpg
#   inflating: img/2011_003642.jpg
#   inflating: img/2011_003643.jpg
#   inflating: img/2011_003644.jpg
#   inflating: img/2011_003647.jpg
#   inflating: img/2011_003650.jpg
#   inflating: img/2011_003652.jpg
#   inflating: img/2011_003656.jpg
#   inflating: img/2011_003657.jpg
#   inflating: img/2011_003658.jpg
#   inflating: img/2011_003659.jpg
#   inflating: img/2011_003662.jpg
#   inflating: img/2011_003664.jpg
#   inflating: img/2011_003665.jpg
#   inflating: img/2011_003666.jpg
#   inflating: img/2011_003667.jpg
#   inflating: img/2011_003668.jpg
#   inflating: img/2011_003669.jpg
#   inflating: img/2011_003673.jpg
#   inflating: img/2011_003674.jpg
#   inflating: img/2011_003675.jpg
#   inflating: img/2011_003677.jpg
#   inflating: img/2011_003681.jpg
#   inflating: img/2011_003684.jpg
#   inflating: img/2011_003688.jpg
#   inflating: img/2011_003689.jpg
#   inflating: img/2011_003691.jpg
#   inflating: img/2011_003693.jpg
#   inflating: img/2011_003694.jpg
#   inflating: img/2011_003705.jpg
#   inflating: img/2011_003706.jpg
#   inflating: img/2011_003708.jpg
#   inflating: img/2011_003709.jpg
#   inflating: img/2011_003711.jpg
#   inflating: img/2011_003712.jpg
#   inflating: img/2011_003714.jpg
#   inflating: img/2011_003715.jpg
#   inflating: img/2011_003716.jpg
#   inflating: img/2011_003719.jpg
#   inflating: img/2011_003720.jpg
#   inflating: img/2011_003721.jpg
#   inflating: img/2011_003724.jpg
#   inflating: img/2011_003726.jpg
#   inflating: img/2011_003727.jpg
#   inflating: img/2011_003730.jpg
#   inflating: img/2011_003731.jpg
#   inflating: img/2011_003734.jpg
#   inflating: img/2011_003740.jpg
#   inflating: img/2011_003746.jpg
#   inflating: img/2011_003748.jpg
#   inflating: img/2011_003749.jpg
#   inflating: img/2011_003751.jpg
#   inflating: img/2011_003752.jpg
#   inflating: img/2011_003754.jpg
#   inflating: img/2011_003755.jpg
#   inflating: img/2011_003756.jpg
#   inflating: img/2011_003758.jpg
#   inflating: img/2011_003760.jpg
#   inflating: img/2011_003761.jpg
#   inflating: img/2011_003763.jpg
#   inflating: img/2011_003764.jpg
#   inflating: img/2011_003766.jpg
#   inflating: img/2011_003767.jpg
#   inflating: img/2011_003768.jpg
#   inflating: img/2011_003769.jpg
#   inflating: img/2011_003773.jpg
#   inflating: img/2011_003775.jpg
#   inflating: img/2011_003777.jpg
#   inflating: img/2011_003778.jpg
#   inflating: img/2011_003780.jpg
#   inflating: img/2011_003781.jpg
#   inflating: img/2011_003783.jpg
#   inflating: img/2011_003789.jpg
#   inflating: img/2011_003791.jpg
#   inflating: img/2011_003792.jpg
#   inflating: img/2011_003801.jpg
#   inflating: img/2011_003803.jpg
#   inflating: img/2011_003805.jpg
#   inflating: img/2011_003806.jpg
#   inflating: img/2011_003807.jpg
#   inflating: img/2011_003810.jpg
#   inflating: img/2011_003811.jpg
#   inflating: img/2011_003817.jpg
#   inflating: img/2011_003820.jpg
#   inflating: img/2011_003822.jpg
#   inflating: img/2011_003823.jpg
#   inflating: img/2011_003824.jpg
#   inflating: img/2011_003826.jpg
#   inflating: img/2011_003829.jpg
#   inflating: img/2011_003834.jpg
#   inflating: img/2011_003836.jpg
#   inflating: img/2011_003841.jpg
#   inflating: img/2011_003842.jpg
#   inflating: img/2011_003844.jpg
#   inflating: img/2011_003846.jpg
#   inflating: img/2011_003848.jpg
#   inflating: img/2011_003849.jpg
#   inflating: img/2011_003850.jpg
#   inflating: img/2011_003857.jpg
#   inflating: img/2011_003858.jpg
#   inflating: img/2011_003860.jpg
#   inflating: img/2011_003861.jpg
#   inflating: img/2011_003862.jpg
#   inflating: img/2011_003869.jpg
#   inflating: img/2011_003871.jpg
#   inflating: img/2011_003874.jpg
#   inflating: img/2011_003876.jpg
#   inflating: img/2011_003878.jpg
#   inflating: img/2011_003879.jpg
#   inflating: img/2011_003884.jpg
#   inflating: img/2011_003885.jpg
#   inflating: img/2011_003886.jpg
#   inflating: img/2011_003887.jpg
#   inflating: img/2011_003891.jpg
#   inflating: img/2011_003892.jpg
#   inflating: img/2011_003894.jpg
#   inflating: img/2011_003898.jpg
#   inflating: img/2011_003900.jpg
#   inflating: img/2011_003905.jpg
#   inflating: img/2011_003906.jpg
#   inflating: img/2011_003907.jpg
#   inflating: img/2011_003908.jpg
#   inflating: img/2011_003909.jpg
#   inflating: img/2011_003911.jpg
#   inflating: img/2011_003912.jpg
#   inflating: img/2011_003913.jpg
#   inflating: img/2011_003917.jpg
#   inflating: img/2011_003920.jpg
#   inflating: img/2011_003921.jpg
#   inflating: img/2011_003924.jpg
#   inflating: img/2011_003926.jpg
#   inflating: img/2011_003929.jpg
#   inflating: img/2011_003931.jpg
#   inflating: img/2011_003933.jpg
#   inflating: img/2011_003937.jpg
#   inflating: img/2011_003938.jpg
#   inflating: img/2011_003940.jpg
#   inflating: img/2011_003941.jpg
#   inflating: img/2011_003942.jpg
#   inflating: img/2011_003943.jpg
#   inflating: img/2011_003944.jpg
#   inflating: img/2011_003949.jpg
#   inflating: img/2011_003951.jpg
#   inflating: img/2011_003952.jpg
#   inflating: img/2011_003953.jpg
#   inflating: img/2011_003959.jpg
#   inflating: img/2011_003960.jpg
#   inflating: img/2011_003966.jpg
#   inflating: img/2011_003967.jpg
#   inflating: img/2011_003972.jpg
#   inflating: img/2011_003973.jpg
#   inflating: img/2011_003974.jpg
#   inflating: img/2011_003977.jpg
#   inflating: img/2011_003978.jpg
#   inflating: img/2011_003979.jpg
#   inflating: img/2011_003980.jpg
#   inflating: img/2011_003981.jpg
#   inflating: img/2011_003984.jpg
#   inflating: img/2011_003988.jpg
#   inflating: img/2011_003990.jpg
#   inflating: img/2011_003991.jpg
#   inflating: img/2011_003995.jpg
#   inflating: img/2011_003997.jpg
#   inflating: img/2011_003998.jpg
#   inflating: img/2011_003999.jpg
#   inflating: img/2011_004007.jpg
#   inflating: img/2011_004008.jpg
#   inflating: img/2011_004009.jpg
#   inflating: img/2011_004011.jpg
#   inflating: img/2011_004013.jpg
#   inflating: img/2011_004014.jpg
#   inflating: img/2011_004015.jpg
#   inflating: img/2011_004020.jpg
#   inflating: img/2011_004022.jpg
#   inflating: img/2011_004025.jpg
#   inflating: img/2011_004026.jpg
#   inflating: img/2011_004028.jpg
#   inflating: img/2011_004029.jpg
#   inflating: img/2011_004030.jpg
#   inflating: img/2011_004031.jpg
#   inflating: img/2011_004032.jpg
#   inflating: img/2011_004033.jpg
#   inflating: img/2011_004034.jpg
#   inflating: img/2011_004036.jpg
#   inflating: img/2011_004037.jpg
#   inflating: img/2011_004038.jpg
#   inflating: img/2011_004039.jpg
#   inflating: img/2011_004042.jpg
#   inflating: img/2011_004043.jpg
#   inflating: img/2011_004044.jpg
#   inflating: img/2011_004045.jpg
#   inflating: img/2011_004046.jpg
#   inflating: img/2011_004048.jpg
#   inflating: img/2011_004049.jpg
#   inflating: img/2011_004050.jpg
#   inflating: img/2011_004052.jpg
#   inflating: img/2011_004053.jpg
#   inflating: img/2011_004054.jpg
#   inflating: img/2011_004056.jpg
#   inflating: img/2011_004057.jpg
#   inflating: img/2011_004058.jpg
#   inflating: img/2011_004059.jpg
#   inflating: img/2011_004060.jpg
#   inflating: img/2011_004062.jpg
#   inflating: img/2011_004063.jpg
#   inflating: img/2011_004067.jpg
#   inflating: img/2011_004068.jpg
#   inflating: img/2011_004069.jpg
#   inflating: img/2011_004073.jpg
#   inflating: img/2011_004074.jpg
#   inflating: img/2011_004077.jpg
#   inflating: img/2011_004079.jpg
#   inflating: img/2011_004080.jpg
#   inflating: img/2011_004081.jpg
#   inflating: img/2011_004082.jpg
#   inflating: img/2011_004083.jpg
#   inflating: img/2011_004084.jpg
#   inflating: img/2011_004086.jpg
#   inflating: img/2011_004088.jpg
#   inflating: img/2011_004089.jpg
#   inflating: img/2011_004091.jpg
#   inflating: img/2011_004093.jpg
#   inflating: img/2011_004096.jpg
#   inflating: img/2011_004097.jpg
# ...
#   inflating: img/2012_003540.jpg
#   inflating: img/2012_003545.jpg
#   inflating: img/2012_003548.jpg
#   inflating: img/2012_003553.jpg
#   inflating: img/2012_003555.jpg
#   inflating: img/2012_003558.jpg
#   inflating: img/2012_003561.jpg
#   inflating: img/2012_003564.jpg
#   inflating: img/2012_003566.jpg
#   inflating: img/2012_003567.jpg
#   inflating: img/2012_003569.jpg
#   inflating: img/2012_003571.jpg
#   inflating: img/2012_003577.jpg
#   inflating: img/2012_003579.jpg
#   inflating: img/2012_003581.jpg
#   inflating: img/2012_003584.jpg
#   inflating: img/2012_003585.jpg
#   inflating: img/2012_003587.jpg
#   inflating: img/2012_003588.jpg
#   inflating: img/2012_003593.jpg
#   inflating: img/2012_003594.jpg
#   inflating: img/2012_003595.jpg
#   inflating: img/2012_003596.jpg
#   inflating: img/2012_003597.jpg
#   inflating: img/2012_003601.jpg
#   inflating: img/2012_003605.jpg
#   inflating: img/2012_003607.jpg
#   inflating: img/2012_003608.jpg
#   inflating: img/2012_003609.jpg
#   inflating: img/2012_003611.jpg
#   inflating: img/2012_003614.jpg
#   inflating: img/2012_003616.jpg
#   inflating: img/2012_003618.jpg
#   inflating: img/2012_003621.jpg
#   inflating: img/2012_003623.jpg
#   inflating: img/2012_003624.jpg
#   inflating: img/2012_003627.jpg
#   inflating: img/2012_003628.jpg
#   inflating: img/2012_003630.jpg
#   inflating: img/2012_003631.jpg
#   inflating: img/2012_003632.jpg
#   inflating: img/2012_003633.jpg
#   inflating: img/2012_003636.jpg
#   inflating: img/2012_003638.jpg
#   inflating: img/2012_003639.jpg
#   inflating: img/2012_003643.jpg
#   inflating: img/2012_003644.jpg
#   inflating: img/2012_003648.jpg
#   inflating: img/2012_003650.jpg
#   inflating: img/2012_003651.jpg
#   inflating: img/2012_003652.jpg
#   inflating: img/2012_003653.jpg
#   inflating: img/2012_003655.jpg
#   inflating: img/2012_003656.jpg
#   inflating: img/2012_003657.jpg
#   inflating: img/2012_003659.jpg
#   inflating: img/2012_003660.jpg
#   inflating: img/2012_003661.jpg
#   inflating: img/2012_003662.jpg
#   inflating: img/2012_003663.jpg
#   inflating: img/2012_003664.jpg
#   inflating: img/2012_003665.jpg
#   inflating: img/2012_003669.jpg
#   inflating: img/2012_003670.jpg
#   inflating: img/2012_003672.jpg
#   inflating: img/2012_003673.jpg
#   inflating: img/2012_003676.jpg
#   inflating: img/2012_003677.jpg
#   inflating: img/2012_003678.jpg
#   inflating: img/2012_003682.jpg
#   inflating: img/2012_003683.jpg
#   inflating: img/2012_003684.jpg
#   inflating: img/2012_003685.jpg
#   inflating: img/2012_003686.jpg
#   inflating: img/2012_003688.jpg
#   inflating: img/2012_003689.jpg
#   inflating: img/2012_003690.jpg
#   inflating: img/2012_003693.jpg
#   inflating: img/2012_003696.jpg
#   inflating: img/2012_003698.jpg
#   inflating: img/2012_003700.jpg
#   inflating: img/2012_003701.jpg
#   inflating: img/2012_003703.jpg
#   inflating: img/2012_003705.jpg
#   inflating: img/2012_003706.jpg
#   inflating: img/2012_003707.jpg
#   inflating: img/2012_003708.jpg
#   inflating: img/2012_003709.jpg
#   inflating: img/2012_003714.jpg
#   inflating: img/2012_003715.jpg
#   inflating: img/2012_003716.jpg
#   inflating: img/2012_003719.jpg
#   inflating: img/2012_003721.jpg
#   inflating: img/2012_003722.jpg
#   inflating: img/2012_003725.jpg
#   inflating: img/2012_003731.jpg
#   inflating: img/2012_003732.jpg
#   inflating: img/2012_003735.jpg
#   inflating: img/2012_003736.jpg
#   inflating: img/2012_003738.jpg
#   inflating: img/2012_003739.jpg
#   inflating: img/2012_003741.jpg
#   inflating: img/2012_003744.jpg
#   inflating: img/2012_003747.jpg
#   inflating: img/2012_003748.jpg
#   inflating: img/2012_003752.jpg
#   inflating: img/2012_003756.jpg
#   inflating: img/2012_003760.jpg
#   inflating: img/2012_003761.jpg
#   inflating: img/2012_003766.jpg
#   inflating: img/2012_003768.jpg
#   inflating: img/2012_003771.jpg
#   inflating: img/2012_003776.jpg
#   inflating: img/2012_003777.jpg
#   inflating: img/2012_003780.jpg
#   inflating: img/2012_003782.jpg
#   inflating: img/2012_003783.jpg
#   inflating: img/2012_003784.jpg
#   inflating: img/2012_003785.jpg
#   inflating: img/2012_003786.jpg
#   inflating: img/2012_003787.jpg
#   inflating: img/2012_003789.jpg
#   inflating: img/2012_003792.jpg
#   inflating: img/2012_003793.jpg
#   inflating: img/2012_003795.jpg
#   inflating: img/2012_003797.jpg
#   inflating: img/2012_003798.jpg
#   inflating: img/2012_003799.jpg
#   inflating: img/2012_003800.jpg
#   inflating: img/2012_003804.jpg
#   inflating: img/2012_003805.jpg
#   inflating: img/2012_003806.jpg
#   inflating: img/2012_003809.jpg
#   inflating: img/2012_003811.jpg
#   inflating: img/2012_003812.jpg
#   inflating: img/2012_003813.jpg
#   inflating: img/2012_003815.jpg
#   inflating: img/2012_003818.jpg
#   inflating: img/2012_003822.jpg
#   inflating: img/2012_003825.jpg
#   inflating: img/2012_003828.jpg
#   inflating: img/2012_003830.jpg
#   inflating: img/2012_003831.jpg
#   inflating: img/2012_003835.jpg
#   inflating: img/2012_003837.jpg
#   inflating: img/2012_003838.jpg
#   inflating: img/2012_003841.jpg
#   inflating: img/2012_003842.jpg
#   inflating: img/2012_003843.jpg
#   inflating: img/2012_003845.jpg
#   inflating: img/2012_003846.jpg
#   inflating: img/2012_003848.jpg
#   inflating: img/2012_003849.jpg
#   inflating: img/2012_003851.jpg
#   inflating: img/2012_003852.jpg
#   inflating: img/2012_003853.jpg
#   inflating: img/2012_003855.jpg
#   inflating: img/2012_003856.jpg
#   inflating: img/2012_003865.jpg
#   inflating: img/2012_003869.jpg
#   inflating: img/2012_003870.jpg
#   inflating: img/2012_003871.jpg
#   inflating: img/2012_003872.jpg
#   inflating: img/2012_003873.jpg
#   inflating: img/2012_003875.jpg
#   inflating: img/2012_003877.jpg
#   inflating: img/2012_003878.jpg
#   inflating: img/2012_003880.jpg
#   inflating: img/2012_003882.jpg
#   inflating: img/2012_003885.jpg
#   inflating: img/2012_003888.jpg
#   inflating: img/2012_003889.jpg
#   inflating: img/2012_003891.jpg
#   inflating: img/2012_003896.jpg
#   inflating: img/2012_003903.jpg
#   inflating: img/2012_003906.jpg
#   inflating: img/2012_003909.jpg
#   inflating: img/2012_003910.jpg
#   inflating: img/2012_003912.jpg
#   inflating: img/2012_003913.jpg
#   inflating: img/2012_003914.jpg
#   inflating: img/2012_003916.jpg
#   inflating: img/2012_003917.jpg
#   inflating: img/2012_003919.jpg
#   inflating: img/2012_003922.jpg
#   inflating: img/2012_003923.jpg
#   inflating: img/2012_003924.jpg
#   inflating: img/2012_003926.jpg
#   inflating: img/2012_003930.jpg
#   inflating: img/2012_003932.jpg
#   inflating: img/2012_003933.jpg
#   inflating: img/2012_003937.jpg
#   inflating: img/2012_003938.jpg
#   inflating: img/2012_003939.jpg
#   inflating: img/2012_003940.jpg
#   inflating: img/2012_003941.jpg
#   inflating: img/2012_003946.jpg
#   inflating: img/2012_003947.jpg
#   inflating: img/2012_003948.jpg
#   inflating: img/2012_003949.jpg
#   inflating: img/2012_003953.jpg
#   inflating: img/2012_003955.jpg
#   inflating: img/2012_003958.jpg
#   inflating: img/2012_003959.jpg
#   inflating: img/2012_003960.jpg
#   inflating: img/2012_003961.jpg
#   inflating: img/2012_003963.jpg
#   inflating: img/2012_003964.jpg
#   inflating: img/2012_003965.jpg
#   inflating: img/2012_003967.jpg
#   inflating: img/2012_003969.jpg
#   inflating: img/2012_003970.jpg
#   inflating: img/2012_003972.jpg
#   inflating: img/2012_003974.jpg
#   inflating: img/2012_003981.jpg
#   inflating: img/2012_003983.jpg
#   inflating: img/2012_003985.jpg
#   inflating: img/2012_003986.jpg
#   inflating: img/2012_003987.jpg
#   inflating: img/2012_003988.jpg
#   inflating: img/2012_003990.jpg
#   inflating: img/2012_003991.jpg
#   inflating: img/2012_003992.jpg
#   inflating: img/2012_003994.jpg
#   inflating: img/2012_003995.jpg
#   inflating: img/2012_003996.jpg
#   inflating: img/2012_004000.jpg
#   inflating: img/2012_004001.jpg
#   inflating: img/2012_004002.jpg
#   inflating: img/2012_004005.jpg
#   inflating: img/2012_004006.jpg
#   inflating: img/2012_004007.jpg
#   inflating: img/2012_004009.jpg
#   inflating: img/2012_004010.jpg
#   inflating: img/2012_004011.jpg
#   inflating: img/2012_004012.jpg
#   inflating: img/2012_004015.jpg
#   inflating: img/2012_004018.jpg
#   inflating: img/2012_004019.jpg
#   inflating: img/2012_004020.jpg
#   inflating: img/2012_004021.jpg
#   inflating: img/2012_004023.jpg
#   inflating: img/2012_004025.jpg
#   inflating: img/2012_004033.jpg
#   inflating: img/2012_004034.jpg
#   inflating: img/2012_004036.jpg
#   inflating: img/2012_004037.jpg
#   inflating: img/2012_004038.jpg
#   inflating: img/2012_004039.jpg
#   inflating: img/2012_004043.jpg
#   inflating: img/2012_004044.jpg
#   inflating: img/2012_004046.jpg
#   inflating: img/2012_004047.jpg
#   inflating: img/2012_004048.jpg
#   inflating: img/2012_004049.jpg
#   inflating: img/2012_004051.jpg
#   inflating: img/2012_004053.jpg
#   inflating: img/2012_004054.jpg
#   inflating: img/2012_004055.jpg
#   inflating: img/2012_004058.jpg
#   inflating: img/2012_004061.jpg
#   inflating: img/2012_004063.jpg
#   inflating: img/2012_004064.jpg
#   inflating: img/2012_004066.jpg
#   inflating: img/2012_004067.jpg
#   inflating: img/2012_004068.jpg
#   inflating: img/2012_004070.jpg
#   inflating: img/2012_004073.jpg
#   inflating: img/2012_004075.jpg
#   inflating: img/2012_004076.jpg
#   inflating: img/2012_004077.jpg
#   inflating: img/2012_004078.jpg
#   inflating: img/2012_004079.jpg
#   inflating: img/2012_004080.jpg
#   inflating: img/2012_004082.jpg
#   inflating: img/2012_004083.jpg
#   inflating: img/2012_004085.jpg
#   inflating: img/2012_004086.jpg
#   inflating: img/2012_004087.jpg
#   inflating: img/2012_004088.jpg
#   inflating: img/2012_004089.jpg
#   inflating: img/2012_004092.jpg
#   inflating: img/2012_004093.jpg
#   inflating: img/2012_004095.jpg
#   inflating: img/2012_004096.jpg
#   inflating: img/2012_004097.jpg
#   inflating: img/2012_004098.jpg
#   inflating: img/2012_004099.jpg
#   inflating: img/2012_004101.jpg
#   inflating: img/2012_004102.jpg
#   inflating: img/2012_004103.jpg
#   inflating: img/2012_004104.jpg
#   inflating: img/2012_004106.jpg
#   inflating: img/2012_004107.jpg
#   inflating: img/2012_004109.jpg
#   inflating: img/2012_004111.jpg
#   inflating: img/2012_004112.jpg
#   inflating: img/2012_004113.jpg
#   inflating: img/2012_004114.jpg
#   inflating: img/2012_004115.jpg
#   inflating: img/2012_004116.jpg
#   inflating: img/2012_004117.jpg
#   inflating: img/2012_004118.jpg
#   inflating: img/2012_004119.jpg
#   inflating: img/2012_004120.jpg
#   inflating: img/2012_004121.jpg
#   inflating: img/2012_004122.jpg
#   inflating: img/2012_004124.jpg
#   inflating: img/2012_004125.jpg
#   inflating: img/2012_004126.jpg
#   inflating: img/2012_004127.jpg
#   inflating: img/2012_004129.jpg
#   inflating: img/2012_004130.jpg
#   inflating: img/2012_004131.jpg
#   inflating: img/2012_004132.jpg
#   inflating: img/2012_004133.jpg
#   inflating: img/2012_004134.jpg
#   inflating: img/2012_004135.jpg
#   inflating: img/2012_004137.jpg
#   inflating: img/2012_004142.jpg
#   inflating: img/2012_004143.jpg
#   inflating: img/2012_004144.jpg
#   inflating: img/2012_004147.jpg
#   inflating: img/2012_004148.jpg
#   inflating: img/2012_004149.jpg
#   inflating: img/2012_004150.jpg
#   inflating: img/2012_004151.jpg
#   inflating: img/2012_004155.jpg
#   inflating: img/2012_004158.jpg
#   inflating: img/2012_004159.jpg
#   inflating: img/2012_004161.jpg
#   inflating: img/2012_004162.jpg
#   inflating: img/2012_004163.jpg
#   inflating: img/2012_004169.jpg
#   inflating: img/2012_004172.jpg
#   inflating: img/2012_004173.jpg
#   inflating: img/2012_004174.jpg
#   inflating: img/2012_004175.jpg
#   inflating: img/2012_004176.jpg
#   inflating: img/2012_004177.jpg
#   inflating: img/2012_004178.jpg
#   inflating: img/2012_004179.jpg
#   inflating: img/2012_004180.jpg
#   inflating: img/2012_004185.jpg
#   inflating: img/2012_004186.jpg
#   inflating: img/2012_004188.jpg
#   inflating: img/2012_004189.jpg
#   inflating: img/2012_004190.jpg
#   inflating: img/2012_004192.jpg
#   inflating: img/2012_004196.jpg
#   inflating: img/2012_004198.jpg
#   inflating: img/2012_004199.jpg
#   inflating: img/2012_004203.jpg
#   inflating: img/2012_004204.jpg
#   inflating: img/2012_004206.jpg
#   inflating: img/2012_004210.jpg
#   inflating: img/2012_004216.jpg
#   inflating: img/2012_004220.jpg
#   inflating: img/2012_004222.jpg
#   inflating: img/2012_004226.jpg
#   inflating: img/2012_004229.jpg
#   inflating: img/2012_004231.jpg
#   inflating: img/2012_004232.jpg
#   inflating: img/2012_004238.jpg
#   inflating: img/2012_004239.jpg
#   inflating: img/2012_004241.jpg
#   inflating: img/2012_004244.jpg
#   inflating: img/2012_004245.jpg
#   inflating: img/2012_004246.jpg
#   inflating: img/2012_004247.jpg
#   inflating: img/2012_004248.jpg
#   inflating: img/2012_004249.jpg
#   inflating: img/2012_004250.jpg
#   inflating: img/2012_004251.jpg
#   inflating: img/2012_004254.jpg
#   inflating: img/2012_004256.jpg
#   inflating: img/2012_004257.jpg
#   inflating: img/2012_004258.jpg
#   inflating: img/2012_004262.jpg
#   inflating: img/2012_004267.jpg
#   inflating: img/2012_004268.jpg
#   inflating: img/2012_004270.jpg
#   inflating: img/2012_004272.jpg
#   inflating: img/2012_004273.jpg
#   inflating: img/2012_004274.jpg
#   inflating: img/2012_004276.jpg
#   inflating: img/2012_004281.jpg
#   inflating: img/2012_004283.jpg
#   inflating: img/2012_004284.jpg
#   inflating: img/2012_004285.jpg
#   inflating: img/2012_004289.jpg
#   inflating: img/2012_004290.jpg
#   inflating: img/2012_004291.jpg
#   inflating: img/2012_004292.jpg
#   inflating: img/2012_004293.jpg
#   inflating: img/2012_004295.jpg
#   inflating: img/2012_004298.jpg
#   inflating: img/2012_004299.jpg
#   inflating: img/2012_004300.jpg
#   inflating: img/2012_004302.jpg
#   inflating: img/2012_004303.jpg
#   inflating: img/2012_004306.jpg
#   inflating: img/2012_004308.jpg
#   inflating: img/2012_004309.jpg
#   inflating: img/2012_004310.jpg
#   inflating: img/2012_004312.jpg
#   inflating: img/2012_004315.jpg
#   inflating: img/2012_004317.jpg
#   inflating: img/2012_004319.jpg
#   inflating: img/2012_004326.jpg
#   inflating: img/2012_004328.jpg
#   inflating: img/2012_004329.jpg
#   inflating: img/2012_004330.jpg
#   inflating: img/2012_004331.jpg
#    creating: list/
#    creating: list/.ipynb_checkpoints/
#   inflating: list/.ipynb_checkpoints/train_aug-checkpoint.txt
#   inflating: list/.ipynb_checkpoints/val-checkpoint.txt
#   inflating: list/train_aug.txt
#   inflating: list/val.txt

# %% [markdown]
# ## 이후, 다음의 셀을 시행하여 이번 실습에 필요한 라이브러리를 import 하자.

# %%
import cv2
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

import torch
import torch.nn as nn
import torch.optim as optim

import torchvision.models as models
import functions

# %% [markdown]
# ### What is Semantic Segmentation?
# #### Segmentation : 이미지를 픽셀 레벨로 이해하는 접근이다.
#
# - 픽셀 하나하나에 대해서 분류 또는 탐지를 하는 task를 의미한다.
#
# - 동일한 label을 가진 모든 픽셀이 동일한 object 또는 class에 속하도록 이미지의 각 픽셀에 label을 할당하는 프로세스를 의미한다.
#
# - 이것은 image level로 예측을 하는 image classification보다 훨씬 어려움
#
# - 동일한 label을 가진 모든 픽셀이 동일한 object 또는 class에 속하도록 이미지의 각 픽셀에 label을 할당하는 프로세스를 의미한다.
#
# <img src="https://drive.google.com/uc?export=view&id=1B2Hch6WUTTDLoGYaxCDbr2Gw-155EO9Z" alt="no_image" style="width: 900px;"/>
#
# semantic segmentation의 적용 분야:
#
# - 자율주행, 로봇공학, 의료영상분석 등 다양한 분야에 응용되는 컴퓨터 비전의 기본 과제이다.
#
# ### Semantic segmentation with CNNs
# - VGG, Resnet 등 classification 에서 쓰이는 모델들은 Semantic Segmentation 에서는 적합하지 않다. 층이 깊어지고, 마지막 층의 Fully Connected Layer 를 통과하면서 많은 파라미터와 차원이 줄어들면서 Object 의 위치정보를 잃기 때문
#
# - 위치 정보를 잃지 않기 위해 Pooling과 FCN 등을 없애고 stride 와 padding 을 일정하게 한다고 하면, 학습량이 너무 많아져서 비효율적이다. 따라서 Downsampling 과 Upsampling 을 활용한다!
#
# - Fully Connected Layer은 하나의 픽셀만을 커버하는 커널, 즉 1x1 커널을 가진 Convolution Layer으로 볼 수 있음이 알려져 있습니다. 따라서, 우리는 사전에 학습된 가중치를 유지하면서 Fully Connected Layer을 Convolution Layer으로 변환할 수 있습니다.

# %% [markdown]
# ### section 1. Pixel 하나하나마다 classification을 해보자.

# %% [markdown]
# **Test image를 Load해보자**

# %%
from PIL import Image
test_img_path = './img/2007_000876.jpg'
test_img = Image.open(test_img_path)
test_img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x334>

# %% [markdown]
# **test image를 normalize한다**

# %%
import torchvision.transforms as transforms
normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]) # ImageNet data들의 평균과 표준편차 값(R,G,B)

transform = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    normalize,
])

test_transform = transform(test_img).cuda().unsqueeze(0)
print(test_transform.size())
# Out:
# torch.Size([1, 3, 224, 224])

# %% [markdown]
# **VGG-Net을 Load한다.**

# %%
import torchvision.models.vgg as vgg # Transfer Learning
imageNet = vgg.vgg16(pretrained=True).cuda() # gpu로 연산
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
# 100%|██████████| 528M/528M [00:03<00:00, 140MB/s]

# %%
import torch
import torch.nn as nn
with torch.no_grad():
    out = imageNet(test_transform)

out_class = torch.argmax(out)
print(out.size())
print(out_class)
# Out:
# torch.Size([1, 1000])
# tensor(285, device='cuda:0')

# %%
# 적당하게 패딩해주자.
m = nn.ZeroPad2d((111,112,111,112))
pad_image = m(test_transform)
img_1by1 = torch.zeros((224,224)).cuda()

# %%
# 픽셀 하나하나마다 연산을 진행한다.
# 이 셀은 시행이 완료되기까지 오랜 시간이 걸린다! 주의하자
for i in range(224):
    for j in range(224):
        patch = pad_image[:,:,i:i+224,j:j+224]
        # classify each pixels
        with torch.no_grad():
            img_1by1[i,j] = torch.argmax(imageNet(patch))

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

plt.subplot(1,2,1)
plt.imshow(test_transform[0].data.cpu().numpy().transpose((1,2,0)))
plt.subplot(1,2,2)
plt.imshow(img_1by1.data.cpu().numpy())
plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# **- 굉장히 비효율적이고, 학습이 잘 되지 않아 성능도 제대로 나오지 않은 것을 볼 수 있다.**

# %% [markdown]
# ### section 2. Upsampling과 Downsampling을 사용하지 않고, 단순히 원래 Classification에 사용했던 모델에서 마지막 Layer만 Fully Connected Layer을 1x1의 Convolution 으로 대체하였을때

# %%
import torchvision.models as models

class VGG_only_Convolution(nn.Module):
    def __init__(self):
        super(VGG_only_Convolution, self).__init__()
        self.features = models.vgg16(pretrained=True).features

        # fc6
        self.fc6 = nn.Conv2d(512, 4096, 7)

        # fc7
        self.fc7 = nn.Conv2d(4096, 4096, 1)

        # fc8 : one by one conv
        self.fc8 = nn.Conv2d(4096, 1000, 1)

        # ReLU
        self.relu = nn.ReLU(inplace=True)

        # Dropout
        self.dropout = nn.Dropout2d()

        self.copy_params_from_vgg16()

    def forward(self, x):
        conv5 = self.features(x)

        fc6 = self.relu(self.fc6(conv5))
        fc7 = self.dropout(fc6)

        fc7 = self.relu(self.fc7(fc7))
        fc8 = self.dropout(fc7)

        score = self.fc8(fc8)

        return score

    def copy_params_from_vgg16(self):
        vgg16 = models.vgg16(pretrained=True)
        for i, name in zip([0, 3, 6], ['fc6', 'fc7', 'fc8']):
            l1 = vgg16.classifier[i]
            l2 = getattr(self, name)
            l2.weight.data.copy_(l1.weight.data.view(l2.weight.size()))
            l2.bias.data.copy_(l1.bias.data.view(l2.bias.size()))

# %%
vgg_only = VGG_only_Convolution().cuda()
vgg_only
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# VGG_only_Convolution(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (fc6): Conv2d(512, 4096, kernel_size=(7, 7), stride=(1, 1))
#   (fc7): Conv2d(4096, 4096, kernel_size=(1, 1), stride=(1, 1))
#   (fc8): Conv2d(4096, 1000, kernel_size=(1, 1), stride=(1, 1))
#   (relu): ReLU(inplace=True)
#   (dropout): Dropout2d(p=0.5, inplace=False)
# )

# %%
transform_conv = transforms.Compose([
    transforms.ToTensor(),
    normalize,
])
test_conv = transform_conv(test_img).cuda().unsqueeze(0)
conv_out = vgg_only(test_conv)
pred = torch.argmax(conv_out, dim=1)
pred
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:456: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return F.conv2d(input, weight, bias, self.stride,
# tensor([[[356, 629, 277, 277, 277, 629, 629, 629, 629],
#          [277, 277, 277, 277, 277, 769, 629, 629, 629],
#          [277, 277, 277, 277, 277, 769, 769, 333, 285],
#          [277, 277, 277, 277, 277, 356, 333, 333, 285]]], device='cuda:0')

# %% [markdown]
# **이 또한, 그다지 좋지 못한 성능을 보이며, 심지어 이미지 사이즈도 변경되었음을 알 수 있다.**

# %% [markdown]
# ## section 3. Bilinear interpolation으로 Upsampling
# - 마지막 layer에 bilinear interpolation을 추가
# - bilinear interpolation은 Pytorch 라이브러리를 이용하면 간편하게 사용 가능
# - bilinear interpolation을 이용하여 네트워크 출력을 입력 크기와 동일하게 만든다.

# %% [markdown]
# <img src="https://drive.google.com/uc?export=view&id=16gx2y7O3m-qfmZfotQQRbbafOLneZT4K" alt="no_image" style="width: 900px;"/>

# %%
class bilinear_upsampled_VGG16(nn.Module):
    def __init__(self):
        super(bilinear_upsampled_VGG16, self).__init__()
        self.features = models.vgg16(pretrained=True).features
        self.features[0].padding = (100,100)  # 이미지 크기를 맞추기 위한 패딩 설정

        # fc6 layer
        self.fc6 = nn.Conv2d(512, 4096, 7)

        # fc7 layer
        self.fc7 = nn.Conv2d(4096, 4096, 1)

        # fc8 layer를 정의하고 PASCAL VOC class를 위해 출력 채널을 21로 설정합니다.
        self.fc8 = nn.Conv2d(4096, 21, 1)

        # ReLU
        self.relu = nn.ReLU(inplace=True)

        # Dropout
        self.dropout = nn.Dropout2d()

        # scaling factor를 32로 설정해주어 upscaling, 원본 이미지 사이즈와 동일하게 키워
        # scaling factor 32이고, bilinear interpolation을 사용하는 upsample layer 계층을 정의합니다. scaling factor를 32로 설정한 이유는 아래에 적어두었습니다.
        self.upsample = nn.Upsample(scale_factor=32, mode='bilinear', align_corners=True)

        # pre-train된 VGG16 모델의 매개변수를 복사합니다.
        self.copy_params_from_vgg16()

    def forward(self, x):
        conv5 = self.features(x)  # 입력을 VGG16의 특징 추출 계층들을 통해 전달합니다.

        fc6 = self.relu(self.fc6(conv5))  # conv5의 출력을 fc6 계층을 통해 전달합니다.
        fc7 = self.dropout(fc6)   # fc6 출력에 드롭아웃을 적용합니다.

        score = self.fc8(fc7)  # fc7의 출력을 fc8 계층을 통해 전달합니다.

        input_size = x.size()[2:]  # 입력 크기(높이, 너비)를 저장합니다.
        upsampled_score = self.upsample(score)   # 이중 선형 업샘플링 계층을 추가합니다.

        # upsampled_score의 크기를 입력 크기와 일치하도록 조정합니다.
        upsampled_score = nn.functional.interpolate(upsampled_score, size=input_size, mode='bilinear', align_corners=True)
        return upsampled_score

    def copy_params_from_vgg16(self): # pre-train된 VGG16 모델의 매개변수를 복사하는 함수입니다. 조금 어려울 수 있으니 이해하지 않고 넘어가셔도 됩니다.
        vgg16 = models.vgg16(pretrained=True)
        for i, name in zip([0, 3], ['fc6', 'fc7']):
            l1 = vgg16.classifier[i]
            l2 = getattr(self, name)
            l2.weight.data.copy_(l1.weight.data.view(l2.weight.size()))
            l2.bias.data.copy_(l1.bias.data.view(l2.bias.size()))

# %% [markdown]
# ## bilinear interpolation 추가 설명
#
# bilinear interpolation은 2차원 공간에서 주어진 점들 사이의 값을 추정하기 위한 선형 보간법의 확장이다. 주로 이미지 처리, 지리정보시스템(GIS), 컴퓨터 그래픽스 등에서 사용되며, 소스 이미지의 해상도를 높이거나 낮추는 과정에서 픽셀 값을 보간하는 데 유용하다.
#
# bilinear interpolation을 통해, 주어진 점 (x, y)의 주변 4개 픽셀 값에 기반하여 새로운 픽셀 값을 추정할 수 있다. 이 방법은 고해상도로 확대한 이미지에서 부드러운 경계 처리와 안티앨리어싱(anti-aliasing) 효과를 제공하며, 비교적 빠른 계산 속도를 가지고 있다. 하지만, 매우 크게 확대할 경우 결과 이미지가 흐릿해질 수 있으며 선명도가 떨어지는 단점이 있다.
#
# 이 코드에서 Upsample 계층에서 scale_factor를 32로 설정하는 이유는 네트워크 출력을 입력 이미지의 원래 크기로 복원하기 위해서이다.
#
# VGG16 아키텍처는 원본 이미지 크기를 줄이면서 특징을 추출한다. 특히, 네트워크를 통해 이미지를 전달할 때마다 여러 풀링 계층이 이미지 크기를 절반으로 줄인다. VGG16에서 5개의 풀링 계층이 있기 때문에 최종 특징 맵의 크기는 원래 입력 이미지 크기의 1/32이다.
#
# 따라서 원본 입력 이미지 크기로 결과를 복원하려면 스케일 팩터를 32로 설정해야 한다. 이렇게 하면 네트워크 출력을 원래 이미지 크기로 빠르게 복원할 수 있으며, 결과적으로 입력 이미지와 동일한 공간 해상도를 가진 세그멘테이션 마스크를 얻을 수 있다.

# %%
bilinear_upsample = bilinear_upsampled_VGG16().cuda()
model_data = torch.load('./bilinear_upsampled_VGG16.pth') # 사전학습된 가중치 파일
bilinear_upsample.load_state_dict(model_data)
# Out:
# <All keys matched successfully>

# %%
with torch.no_grad():
    conv_out = bilinear_upsample(test_conv)
output = torch.argmax(conv_out, dim=1)

vis_output = functions.segmentation_output(output[0].data.cpu().numpy())

plt.subplot(1,2,1)
plt.imshow(test_conv[0].data.cpu().numpy().transpose((1,2,0)))
plt.subplot(1,2,2)
plt.imshow(vis_output)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ### section 4. 인코더/디코더 구조의 CNN 모델

# %% [markdown]
# #### Transposed Convolution (디코더)
#
# <img src="https://drive.google.com/uc?export=view&id=1O6DOA0txVouNBMjOsZQz8i_-3ksn57bm"  onerror="this.style.display='none'" /><br><br>
#
#
# - Transposed Convolution("Deconvolution"이라고 함)은 학습 가능한 필터를 사용하여 입력 해상도를 디코딩(Upsampling)하는 데 사용됩니다. 공간 정보를 하나의 지점으로 압축하는 표준 Convolution과 달리 입력 지점을 여러 공간 위치에 분산시킵니다.
# - 예를 들어 stride가 2인 3×3 Deconvolution 커널은 2×2(청록색 사각형) 입력을 5×5(파란색 사각형) 출력으로 변환합니다.

# %% [markdown]
# #### Dilated Convolution
# <img src="https://drive.google.com/uc?export=view&id=1lbDUeAu-2TR8SqnsniooriD5OA0CoZl-"  onerror="this.style.display='none'" /><br><br>
#
# - The dilated convolution은 일반 convolution에 'Dilation rate'을 적용한 것이다.
#
# - The dilated convolution은 추가적인 매개변수 없이 필터가 커버하는 영역을 확대한다. Dilation rate은 확대하는 간격의 크기이다.
#
# - 예를 들어, Dilation rate이 2인 3×3 커널은 5×5 커널과 동일한 receptive field(수용 영역)를 갖지만 여전히 9개의 매개변수만 사용하는 반면 5×5는 25개의 매개변수를 사용합니다.

# %% [markdown]
# ### FCN8s model 구조

# %% [markdown]
# <img src="https://drive.google.com/uc?export=view&id=1b9GQsVlL6lecP54_lHTSbocyGHCf-g_g"  onerror="this.style.display='none'" /><br><br>
#
# <p style='text-align:right;'>[<a href='https://medium.com/@wilburdes/semantic-segmentation-using-fully-convolutional-neural-networks-86e45336f99b'>source</a>]</p>

# %% [markdown]
# ## ** FCN8에서 8은 모델의 깊이

# %% [markdown]
# ## 다음과 같은 구조로 모델이 형성된다.
#
# - Predict 1: $1\times1$ Conv(in: 4096, out: n_class)
# - Predict 2: $1\times1$ Conv(in: 512, out: n_class), weight = 0.01
# - Predict 3: $1\times1$ Conv(in: 256, out: n_class), weight = 0.0001
#
# - Deconv 1: $4\times4$ Transposed Conv (in: n_class, out: n_class, stride: 2, biase: False)
# - Deconv 2: $4\times4$ Transposed Conv (in: n_class, out: n_class, stride: 2, biase: False)
# - Deconv 3: $16\times16$ Transposed Conv (in: n_class, out: n_class, stride: 8, biase: False)

# %%
class FCN8s(nn.Module):
    def __init__(self, n_class=21):
        super(FCN8s, self).__init__()
        # pre-train된 VGG weight들을 불러온다.
        self.features = models.vgg16(pretrained=True).features

        # fc6 layer
        self.fc6 = nn.Conv2d(512, 4096, 7)


        # fc6 layer
        self.fc7 = nn.Conv2d(4096, 4096, 1)


        # ReLU
        self.relu = nn.ReLU(inplace=True)

        # Dropout
        self.dropout = nn.Dropout2d()


        # 각 단계에 대한 prediction convolutions (Downsampling) 을 정의
        self.predict_conv1 = nn.Conv2d(4096, n_class, kernel_size=1)
        self.predict_conv2 = nn.Conv2d(512, n_class, kernel_size=1)
        self.predict_conv3 = nn.Conv2d(256, n_class, kernel_size=1)

        # Upscaling prediction (Upsampling)을 위한 Deconvolution layer를 정의
        self.deconv1 = nn.ConvTranspose2d(n_class, n_class, kernel_size=4, stride=2, bias=False)
        self.deconv2 = nn.ConvTranspose2d(n_class, n_class, kernel_size=4, stride=2, bias=False)
        self.deconv3 = nn.ConvTranspose2d(n_class, n_class, kernel_size=16, stride=8, bias=False)

        self._initialize_weights()
        self.copy_params_from_vgg16()

    def _initialize_weights(self):
        self.features[0].padding = (100,100)

        # MaxPool2d layer와 ConvTranspose2d layer의 초기화. 이해가 어려우면 넘어가셔도 좋습니다.
        for m in self.modules():
            if isinstance(m, nn.MaxPool2d):
                m.ceil_mode = True
            if isinstance(m, nn.ConvTranspose2d):
                assert m.kernel_size[0] == m.kernel_size[1]
                initial_weight = functions.get_upsampling_weight(
                    m.in_channels, m.out_channels, m.kernel_size[0])
                m.weight.data.copy_(initial_weight)

    def forward(self, x):
        initial = x
        # VGG 네트워크를 통과시키고, pool3와 pool4의 결과를 저장한다.
        for idx, layer in enumerate(self.features):
            x = layer(x)
            if idx == 16:
                pool3 = x.clone()
            elif idx == 23:
                pool4 = x.clone()

        # Pass through fc6 layer
        x = self.dropout(self.relu(self.fc6(x)))

        # Pass through fc7 layer
        x = self.dropout(self.relu(self.fc7(x)))

        # Pass through Prediction 1 and Deconvolution 1
        x = self.predict_conv1(x)
        x = self.deconv1(x)
        deconv1 = x

        # Pass through Prediction 2
        x = self.predict_conv2(pool4)
        x = x[:, :, 5:5 + deconv1.size(2), 5:5 + deconv1.size(3)] # Crop boundary
        predict2 = x

        # Add deconv1 and predict2, then pass through Deconvolution 2
        x = deconv1 + predict2 * 0.01
        x = self.deconv2(x)
        deconv2 = x

        # Pass through Prediction 3
        x = self.predict_conv3(pool3)
        x = x[:, :, 9:9 + deconv2.size(2), 9:9 + deconv2.size(3)] # Crop boundary
        predict3 = x

        # Add predict3 and deconv2
        x = predict3 * 0.0001 + deconv2

        # Pass through Deconvolution 3
        x = self.deconv3(x)
        x = x[:, :, 31:31+initial.size(2), 31:31+initial.size(3)].contiguous() # Crop boundary
        return x

    def copy_params_from_vgg16(self): # pre-train된 VGG16 모델의 매개변수를 복사하는 함수입니다. 조금 어려울 수 있으니 이해하지 않고 넘어가셔도 됩니다.
        vgg16 = models.vgg16(pretrained=True)
        for i, name in zip([0, 3], ['fc6', 'fc7']):
            l1 = vgg16.classifier[i]
            l2 = getattr(self, name)
            l2.weight.data.copy_(l1.weight.data.view(l2.weight.size()))
            l2.bias.data.copy_(l1.bias.data.view(l2.bias.size()))

# %% [markdown]
# ## FCN8 (Fully Convolutional Network with 8-stride)
#
# FCN8 (Fully Convolutional Network with 8-stride)는 세멘틱 분할(Semantic Segmentation)을 수행하기 위한 딥러닝 아키텍처입니다. 세멘틱 분할은 이미지의 각 픽셀에 레이블을 할당하는 작업으로, 객체 인식 및 분류와 달리 이미지에서 객체의 정확한 위치와 경계를 파악할 수 있게 해줍니다.
#
# FCN8은 기존의 VGG16 네트워크를 기반으로 구축되었으며, 기존의 전연결 계층(Fully Connected Layers)를 컨볼루션 계층(Convolutional Layers)으로 바꾸어 공간 정보를 유지하면서 특징 추출이 가능하게 합니다. 이러한 변형을 통해 FCN은 입력 이미지의 크기에 관계없이 동작할 수 있습니다.
#
# FCN8의 주요 특징은 다음과 같습니다:
#
# 스킵 커넥션(Skip Connections): FCN8은 여러 해상도의 특징 맵을 결합하여 세부 정보와 전체적인 구조 정보를 모두 활용합니다. 이를 위해 풀링 계층(pool3, pool4)에서 추출한 특징 맵과 최종 컨볼루션 계층에서 얻은 특징 맵을 결합합니다. 이를 통해 높은 수준의 추상화와 높은 해상도의 세부 정보를 동시에 활용할 수 있습니다.
#
# 업샘플링(Up-sampling): FCN8은 세 개의 디컨볼루션(Deconvolution) 계층을 사용하여 특징 맵을 원본 이미지 크기로 업샘플링합니다. 이를 통해 각 픽셀에 대한 예측이 가능하게 됩니다.
#
# FCN8의 동작 과정은 다음과 같습니다:
#
# VGG16의 컨볼루션 계층을 사용하여 이미지에서 특징을 추출합니다.
# 전연결 계층 대신 컨볼루션 계층을 사용하여 공간 정보를 유지하면서 특징을 처리합니다.
# 스킵 커넥션을 사용하여 여러 해상도의 특징 맵을 결합합니다.
# 디컨볼루션 계층을 사용하여 원본 이미지 크기로 업샘플링합니다.
# 최종 예측을 생성하고, 각 픽셀에 레이블을 할당합니다.
# FCN8은 세멘틱 분할 작업에서 높은 성능을 보여주며, 다양한 환경에서 객체의 정확한 위치와 경계를 파악할 수 있습니다. 이러한 이유로 FCN8은 이미지 분할, 객체 인식, 자율주행차 등 다양한 분야에서 사용되고 있습니다.
#
# FCN8의 단점 중 하나는 속도입니다. 디컨볼루션 연산이 복잡하고, 스킵 커넥션을 통한 특징 맵 결합 과정이 연산량을 증가시키기 때문입니다. 이러한 문제를 해결하기 위해 다양한 연구가 진행되고 있으며, 이를 바탕으로 개선된 네트워크 구조와 효율적인 연산 방법이 제안되고 있습니다.

# %% [markdown]
# 이 아래의 Data load 셀은 수정하거나 코드 추가 없이 그냥 실행해주시면 됩니다.

# %% [markdown]
# **Data load**

# %%
img_list = functions.read_file('./list/train_aug.txt')
data_list = []

for i in range(10):
    np.random.shuffle(img_list)
    data_list.extend(img_list)
data_gen = functions.chunker(data_list, 1)

# %%
model = FCN8s().cuda()

# %% [markdown]
# # section 5.
#
# 적절한 learning rate와 max_iter(epoch)를 설정하여 FCN 모델을 학습시켜보자. 우리의 목표는 다음과 같다.
#
# (1) mIoU는 bilinear interpolation만을 사용한 모델보다 높아야 한다.
#
# (2) 또한, FCN-8의 mIoU는 0.45를 넘겨야 한다.

# %%
lr = 0.00001

optimizer = optim.Adam(model.parameters(), lr=lr)
optimizer.zero_grad()
criterion = nn.CrossEntropyLoss() # cross-entropy loss 함수 사용
max_iter = 30000

# %% [markdown]
# - cross-entropy loss를 사용합니다.
# - 100 iterations 마다 training loss를 출력합니다.
# - training loss가 점진적으로 감소하는 것을 관찰해보세요.

# %%
running_loss = 0.0
for iter in range(max_iter + 1):
    inputs, label = functions.get_data(next(data_gen))
    # training loop
    model.train()
    inputs = torch.tensor(inputs).cuda()
    label = torch.tensor(label).long().cuda()

    optimizer.zero_grad()

    output = model(inputs)
    loss = criterion(output, label)

    loss.backward()
    optimizer.step()

    running_loss += loss.item()
    if (iter % 100 == 0) & (iter != 0):
        print(f'Iteration: {iter}, Loss: {running_loss / (iter+1)}')
# Out:
# <ipython-input-25-102bcb7e3674>:6: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   inputs = torch.tensor(inputs).cuda()
# /usr/local/lib/python3.10/dist-packages/torch/autograd/graph.py:744: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# Iteration: 100, Loss: 3.4866909709307228
# Iteration: 200, Loss: 2.575235758180642
# Iteration: 300, Loss: 2.220159384251829
# Iteration: 400, Loss: 2.046157780913938
# Iteration: 500, Loss: 1.9288822428700692
# Iteration: 600, Loss: 1.8437733260198759
# Iteration: 700, Loss: 1.7587737588905403
# Iteration: 800, Loss: 1.7033550452147976
# Iteration: 900, Loss: 1.664197256170486
# Iteration: 1000, Loss: 1.6222180717203256
# Iteration: 1100, Loss: 1.5835694321139389
# Iteration: 1200, Loss: 1.5516715559295746
# Iteration: 1300, Loss: 1.5231310236156788
# Iteration: 1400, Loss: 1.4967460872394052
# Iteration: 1500, Loss: 1.465116682650396
# Iteration: 1600, Loss: 1.439053672686368
# Iteration: 1700, Loss: 1.4103640088891454
# Iteration: 1800, Loss: 1.3864301968622397
# Iteration: 1900, Loss: 1.3626099875238946
# Iteration: 2000, Loss: 1.3435066593545621
# Iteration: 2100, Loss: 1.324813992804584
# Iteration: 2200, Loss: 1.310677359744683
# Iteration: 2300, Loss: 1.2978429435851495
# Iteration: 2400, Loss: 1.2763281956102477
# Iteration: 2500, Loss: 1.266367063138549
# Iteration: 2600, Loss: 1.2525740923443778
# Iteration: 2700, Loss: 1.2403176752915928
# Iteration: 2800, Loss: 1.2248862333355026
# Iteration: 2900, Loss: 1.2148327367172873
# Iteration: 3000, Loss: 1.2030821992354377
# Iteration: 3100, Loss: 1.188463603595968
# Iteration: 3200, Loss: 1.1742482514803492
# Iteration: 3300, Loss: 1.1642662952678045
# Iteration: 3400, Loss: 1.1571873047445775
# Iteration: 3500, Loss: 1.1468610232900769
# Iteration: 3600, Loss: 1.1386872601215086
# Iteration: 3700, Loss: 1.1297102999777584
# Iteration: 3800, Loss: 1.1228207451490093
# Iteration: 3900, Loss: 1.1146302338182483
# Iteration: 4000, Loss: 1.1059181477396869
# Iteration: 4100, Loss: 1.096611122953415
# Iteration: 4200, Loss: 1.0892975590865943
# Iteration: 4300, Loss: 1.080545727269223
# Iteration: 4400, Loss: 1.0711433854202936
# Iteration: 4500, Loss: 1.061083680034508
# Iteration: 4600, Loss: 1.0514228079416192
# Iteration: 4700, Loss: 1.0450222864897611
# Iteration: 4800, Loss: 1.0377746406283832
# Iteration: 4900, Loss: 1.0313351059633113
# Iteration: 5000, Loss: 1.0260575129930805
# Iteration: 5100, Loss: 1.0212280481354123
# Iteration: 5200, Loss: 1.013686363083013
# Iteration: 5300, Loss: 1.009766932136269
# Iteration: 5400, Loss: 1.0055393142788813
# Iteration: 5500, Loss: 1.0005612277402631
# Iteration: 5600, Loss: 0.9953210953831901
# Iteration: 5700, Loss: 0.9911300099956829
# Iteration: 5800, Loss: 0.9849344360398267
# Iteration: 5900, Loss: 0.9798703653700972
# Iteration: 6000, Loss: 0.977283237834716
# Iteration: 6100, Loss: 0.9711936077033104
# Iteration: 6200, Loss: 0.9658204038519159
# Iteration: 6300, Loss: 0.9610713182271137
# Iteration: 6400, Loss: 0.9549148153313467
# Iteration: 6500, Loss: 0.9503715859788818
# Iteration: 6600, Loss: 0.9467291145604806
# Iteration: 6700, Loss: 0.9426792996300812
# Iteration: 6800, Loss: 0.9394530419963034
# Iteration: 6900, Loss: 0.9350135617887709
# Iteration: 7000, Loss: 0.9312861222002765
# Iteration: 7100, Loss: 0.9273779110230455
# Iteration: 7200, Loss: 0.9233881465474022
# Iteration: 7300, Loss: 0.9220021676719637
# Iteration: 7400, Loss: 0.91821995080363
# Iteration: 7500, Loss: 0.913775335645226
# Iteration: 7600, Loss: 0.9089707642249149
# Iteration: 7700, Loss: 0.9058174711657301
# Iteration: 7800, Loss: 0.9018073228477129
# Iteration: 7900, Loss: 0.8984828589580988
# Iteration: 8000, Loss: 0.8947061288088222
# Iteration: 8100, Loss: 0.8915357177934776
# Iteration: 8200, Loss: 0.88843473149099
# Iteration: 8300, Loss: 0.885090980198943
# Iteration: 8400, Loss: 0.8823573026903007
# Iteration: 8500, Loss: 0.8786347481035289
# Iteration: 8600, Loss: 0.8743923828510379
# Iteration: 8700, Loss: 0.8711200519733036
# Iteration: 8800, Loss: 0.8680996608365581
# Iteration: 8900, Loss: 0.8650017194480245
# Iteration: 9000, Loss: 0.8614457536362746
# Iteration: 9100, Loss: 0.859393985667859
# Iteration: 9200, Loss: 0.857053288822406
# Iteration: 9300, Loss: 0.854099358752015
# Iteration: 9400, Loss: 0.8520907501161769
# Iteration: 9500, Loss: 0.8490969104640975
# Iteration: 9600, Loss: 0.8462043238686177
# Iteration: 9700, Loss: 0.8435456763870216
# Iteration: 9800, Loss: 0.8412328292526865
# Iteration: 9900, Loss: 0.8386488493413234
# Iteration: 10000, Loss: 0.8362608810718375
# Iteration: 10100, Loss: 0.8335581116173436
# Iteration: 10200, Loss: 0.8309270287794525
# Iteration: 10300, Loss: 0.8290102301457398
# Iteration: 10400, Loss: 0.8258232212306318
# Iteration: 10500, Loss: 0.8223440071452863
# Iteration: 10600, Loss: 0.8206753931914037
# Iteration: 10700, Loss: 0.8177331676627908
# Iteration: 10800, Loss: 0.8147582265790012
# Iteration: 10900, Loss: 0.8133520146391625
# Iteration: 11000, Loss: 0.8105798151143675
# Iteration: 11100, Loss: 0.8083397937592838
# Iteration: 11200, Loss: 0.8050853086663491
# Iteration: 11300, Loss: 0.8026225626514066
# Iteration: 11400, Loss: 0.8000258567528001
# Iteration: 11500, Loss: 0.7974785802524811
# Iteration: 11600, Loss: 0.795130037112967
# Iteration: 11700, Loss: 0.794348004015312
# Iteration: 11800, Loss: 0.7917804862964863
# Iteration: 11900, Loss: 0.7891011244327308
# Iteration: 12000, Loss: 0.7872154845562556
# Iteration: 12100, Loss: 0.7848760756966363
# Iteration: 12200, Loss: 0.7823931921228282
# Iteration: 12300, Loss: 0.7805421722574516
# Iteration: 12400, Loss: 0.7783287506602821
# Iteration: 12500, Loss: 0.7762248252871827
# Iteration: 12600, Loss: 0.7738178272140851
# Iteration: 12700, Loss: 0.7721118784060327
# Iteration: 12800, Loss: 0.7698384150608055
# Iteration: 12900, Loss: 0.7681143743692547
# Iteration: 13000, Loss: 0.7657441792206041
# Iteration: 13100, Loss: 0.7639615904132063
# Iteration: 13200, Loss: 0.7616533905100654
# Iteration: 13300, Loss: 0.7597107845553553
# Iteration: 13400, Loss: 0.7581856104340072
# Iteration: 13500, Loss: 0.7567339096580226
# Iteration: 13600, Loss: 0.7551367227735135
# Iteration: 13700, Loss: 0.7537703837041223
# Iteration: 13800, Loss: 0.7527365715042973
# Iteration: 13900, Loss: 0.7511428318676965
# Iteration: 14000, Loss: 0.7505582782863144
# Iteration: 14100, Loss: 0.748975442291552
# Iteration: 14200, Loss: 0.7470332146202191
# Iteration: 14300, Loss: 0.7458738970067713
# Iteration: 14400, Loss: 0.7447104296398612
# Iteration: 14500, Loss: 0.7435513870693237
# Iteration: 14600, Loss: 0.7426078120776199
# Iteration: 14700, Loss: 0.7408676036670865
# Iteration: 14800, Loss: 0.7388331907096026
# Iteration: 14900, Loss: 0.7374418246108606
# Iteration: 15000, Loss: 0.7354043941762559
# Iteration: 15100, Loss: 0.7339102270493738
# Iteration: 15200, Loss: 0.7322828536151685
# Iteration: 15300, Loss: 0.7305882659722912
# Iteration: 15400, Loss: 0.7294630850796797
# Iteration: 15500, Loss: 0.7280676220237567
# Iteration: 15600, Loss: 0.7263933443525528
# Iteration: 15700, Loss: 0.7247323715211343
# Iteration: 15800, Loss: 0.7236279074701065
# Iteration: 15900, Loss: 0.7224415068068458
# Iteration: 16000, Loss: 0.7205068902111962
# Iteration: 16100, Loss: 0.7195071490381371
# Iteration: 16200, Loss: 0.7186469935284224
# Iteration: 16300, Loss: 0.7178141137557449
# Iteration: 16400, Loss: 0.7166517944473851
# Iteration: 16500, Loss: 0.7159106616109937
# Iteration: 16600, Loss: 0.7148475391067922
# Iteration: 16700, Loss: 0.7136726039276374
# Iteration: 16800, Loss: 0.7122684668476954
# Iteration: 16900, Loss: 0.7108722822147748
# Iteration: 17000, Loss: 0.7101891553240871
# Iteration: 17100, Loss: 0.7095267864917484
# Iteration: 17200, Loss: 0.7087454441633244
# Iteration: 17300, Loss: 0.7075256034845716
# Iteration: 17400, Loss: 0.7064743109412588
# Iteration: 17500, Loss: 0.7052623838738161
# Iteration: 17600, Loss: 0.7037072722576995
# Iteration: 17700, Loss: 0.70223000056604
# Iteration: 17800, Loss: 0.700971621414916
# Iteration: 17900, Loss: 0.6999677893608689
# Iteration: 18000, Loss: 0.6994817791227836
# Iteration: 18100, Loss: 0.6982636348430619
# Iteration: 18200, Loss: 0.6971494012074672
# Iteration: 18300, Loss: 0.6968263994382947
# Iteration: 18400, Loss: 0.6953768583306288
# Iteration: 18500, Loss: 0.6942857518924493
# Iteration: 18600, Loss: 0.6930305170776545
# Iteration: 18700, Loss: 0.6922167784001129
# Iteration: 18800, Loss: 0.6912329513142453
# Iteration: 18900, Loss: 0.6899812498908331
# Iteration: 19000, Loss: 0.6897211002562028
# Iteration: 19100, Loss: 0.6887743555461203
# Iteration: 19200, Loss: 0.688136478671791
# Iteration: 19300, Loss: 0.686937873067339
# Iteration: 19400, Loss: 0.6858983015966124
# Iteration: 19500, Loss: 0.6852454685665378
# Iteration: 19600, Loss: 0.6840027834226627
# Iteration: 19700, Loss: 0.6829722283644551
# Iteration: 19800, Loss: 0.6820127999375557
# Iteration: 19900, Loss: 0.6812314464039854
# Iteration: 20000, Loss: 0.6800208271090054
# Iteration: 20100, Loss: 0.6789164116946796
# Iteration: 20200, Loss: 0.6778299551647617
# Iteration: 20300, Loss: 0.6770005591762515
# Iteration: 20400, Loss: 0.6761306861484575
# Iteration: 20500, Loss: 0.6751933901040227
# Iteration: 20600, Loss: 0.6748281269797454
# Iteration: 20700, Loss: 0.6740911959724561
# Iteration: 20800, Loss: 0.6731801643823863
# Iteration: 20900, Loss: 0.6724611241552462
# Iteration: 21000, Loss: 0.6714533347637835
# Iteration: 21100, Loss: 0.6707212460996785
# Iteration: 21200, Loss: 0.6700996449076411
# Iteration: 21300, Loss: 0.6688322343212176
# Iteration: 21400, Loss: 0.6678482993840286
# Iteration: 21500, Loss: 0.6668305882556567
# Iteration: 21600, Loss: 0.6655168551682826
# Iteration: 21700, Loss: 0.6644696845627276
# Iteration: 21800, Loss: 0.663349396451445
# Iteration: 21900, Loss: 0.6625769891488936
# Iteration: 22000, Loss: 0.6614868814758462
# Iteration: 22100, Loss: 0.6606816548463186
# Iteration: 22200, Loss: 0.6596777822916006
# Iteration: 22300, Loss: 0.658881423708269
# Iteration: 22400, Loss: 0.6578390217113205
# Iteration: 22500, Loss: 0.6567733070018343
# Iteration: 22600, Loss: 0.65581220746826
# Iteration: 22700, Loss: 0.6552107886883126
# Iteration: 22800, Loss: 0.6543127071691546
# Iteration: 22900, Loss: 0.6537424828730911
# Iteration: 23000, Loss: 0.6527850962600938
# Iteration: 23100, Loss: 0.6517747986650645
# Iteration: 23200, Loss: 0.6507462193172605
# Iteration: 23300, Loss: 0.6497710021275249
# Iteration: 23400, Loss: 0.6487484165064323
# Iteration: 23500, Loss: 0.6477799686316492
# Iteration: 23600, Loss: 0.6468223264170546
# Iteration: 23700, Loss: 0.646195329108443
# Iteration: 23800, Loss: 0.6453232094671522
# Iteration: 23900, Loss: 0.6445680900063757
# Iteration: 24000, Loss: 0.6439039281536127
# Iteration: 24100, Loss: 0.6430252073037246
# Iteration: 24200, Loss: 0.642462108190741
# Iteration: 24300, Loss: 0.6418517886741552
# Iteration: 24400, Loss: 0.6417421544532185
# Iteration: 24500, Loss: 0.6408581295084359
# Iteration: 24600, Loss: 0.6398954698663188
# Iteration: 24700, Loss: 0.6391710820071127
# Iteration: 24800, Loss: 0.6383383290227903
# Iteration: 24900, Loss: 0.6377028786714508
# Iteration: 25000, Loss: 0.6368109752676961
# Iteration: 25100, Loss: 0.6363073882972363
# Iteration: 25200, Loss: 0.6352407081591624
# Iteration: 25300, Loss: 0.6344771958090794
# Iteration: 25400, Loss: 0.6336430878496915
# Iteration: 25500, Loss: 0.6330699537119292
# Iteration: 25600, Loss: 0.6322783748893006
# Iteration: 25700, Loss: 0.6314382660241274
# Iteration: 25800, Loss: 0.6307175012725469
# Iteration: 25900, Loss: 0.6301249349247817
# Iteration: 26000, Loss: 0.6294801943664987
# Iteration: 26100, Loss: 0.6287170982273478
# Iteration: 26200, Loss: 0.6279644008966097
# Iteration: 26300, Loss: 0.626975507949383
# Iteration: 26400, Loss: 0.6262838032563784
# Iteration: 26500, Loss: 0.6260264206073463
# Iteration: 26600, Loss: 0.6250895141959458
# Iteration: 26700, Loss: 0.624500340989797
# Iteration: 26800, Loss: 0.6238572914287992
# Iteration: 26900, Loss: 0.6232560420788665
# Iteration: 27000, Loss: 0.6226224001200709
# Iteration: 27100, Loss: 0.6217352319946772
# Iteration: 27200, Loss: 0.6212302413821794
# Iteration: 27300, Loss: 0.6205618795936061
# Iteration: 27400, Loss: 0.6198745024461079
# Iteration: 27500, Loss: 0.6192643136936418
# Iteration: 27600, Loss: 0.6185416772999982
# Iteration: 27700, Loss: 0.6180025064509479
# Iteration: 27800, Loss: 0.6170483608353602
# Iteration: 27900, Loss: 0.6164016914848348
# Iteration: 28000, Loss: 0.6157484568167662
# Iteration: 28100, Loss: 0.615083821793096
# Iteration: 28200, Loss: 0.6144659495884256
# Iteration: 28300, Loss: 0.613843071954959
# Iteration: 28400, Loss: 0.61309807578757
# Iteration: 28500, Loss: 0.6123040167537765
# Iteration: 28600, Loss: 0.6115973155201093
# Iteration: 28700, Loss: 0.6108794363017561
# Iteration: 28800, Loss: 0.6102264649665595
# Iteration: 28900, Loss: 0.6094033041809301
# Iteration: 29000, Loss: 0.6087895671380282
# Iteration: 29100, Loss: 0.6079512618474816
# Iteration: 29200, Loss: 0.6071205811398301
# Iteration: 29300, Loss: 0.6063508633265452
# Iteration: 29400, Loss: 0.6058970066727911
# Iteration: 29500, Loss: 0.6052127866275097
# Iteration: 29600, Loss: 0.6043951944230176
# Iteration: 29700, Loss: 0.6037040648041293
# Iteration: 29800, Loss: 0.6030946637086191
# Iteration: 29900, Loss: 0.6024991761875467
# Iteration: 30000, Loss: 0.6019140726072026

# %% [markdown]
# ### section 6. 결과 관찰
# - 아래의 'validation_miou' 함수를 이용하여 우리가 만든 FCN 모델이 bilinear interpolation 만을 사용한 모델 만큼의 성능이 나오는지 확인해보자.
# - network의 output을 보기 위해 위에서 정의한 'segmentation_output' 함수를 이용할 것이다.

# %% [markdown]
# **아래의 코드는 추가로 입력할 필요 없이 실행만 해주시면 됩니다.**

# %%
fcn8s_miou = functions.validation_miou(model)
bilinearVgg_miou = functions.validation_miou(bilinear_upsample)
# Out:
# mIoU 계산 시작!
# mIoU =  0.4727899138311506
# mIoU 계산 시작!
# mIoU =  0.4327722477715352

# %%
print('FCN-8의 mIoU =', fcn8s_miou)
print('bilinear로 upsample된 모델의 mIoU =', bilinearVgg_miou)
# Out:
# FCN-8의 mIoU = 0.4727899138311506
# bilinear로 upsample된 모델의 mIoU = 0.4327722477715352

# %% [markdown]
# # *** FCN8의 mIoU가 bilinear upsampled VGG-16의 mIoU보다 높게 측정되면, 실습에 성공한 것이다!!***

# %% [markdown]
# ## Discussion :
# FCN8의 mIoU가 더 높게 나왔으며, 따라서 성능이 Bilinear Interpolation에 비해 더 좋은 것을 확인 할 수 있었다. 그러나 FCN8을 학습시키는 데 꽤 많은 시간과 컴퓨터 자원(메모리 등)이 필요했으며 연산에 더 오랜 시간이 걸렸다. 따라서 정확한 Semantic Segmentation을 위해서는 FCN8을 충분히 이용할 가치가 있지만, 간단하고 빠른 계산을 위해선 Bilinear Interpolation이 적절하게 이용될 수도 있다. 많은 논문들이 CNN 모듈과 Bilinear Interpolation을 적절히 섞어서 사용한다.

# %%
# Visualize the result
with torch.no_grad():
    conv_out_model = model(test_conv)
output_model = torch.argmax(conv_out_model, dim=1)

vis_output_model = functions.segmentation_output(output_model[0].data.cpu().numpy())

plt.subplot(1,2,1)
plt.imshow(test_conv[0].data.cpu().numpy().transpose((1,2,0)))
plt.subplot(1,2,2)
plt.imshow(vis_output_model)

# %% [markdown]
# ### *References*
# FCN official code (https://github.com/shelhamer/fcn.berkeleyvision.org)
#
# Upsampling method (https://towardsdatascience.com/types-of-convolutions-in-deep-learning-717013397f4d)
#
# Cs231n (http://cs231n.stanford.edu/slides/2017/cs231n_2017_lecture11.pdf)
